# %%
import pandas as pd
import numpy as np

import tqdm
import datetime

import tensorflow as tf
from tensorflow.keras import Model,Sequential
from tensorflow.keras.layers import Activation,Dense,Dot,Flatten,GlobalAveragePooling1D,Reshape,Embedding
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %%
movies=pd.read_csv(r'./ml-latest-small/movies.csv')
data=pd.read_csv(r'./ml-latest-small/ratings.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
data.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# 过滤到评分低于3.5分以下的
data=data[data.rating>=3.5]
data=data.merge(movies,left_on='movieId',right_on='movieId')
data=data.sort_values(['userId','timestamp'])
data.reset_index(drop=True,inplace=True)

# %%
data.head()
# Out:
#    userId  movieId  rating  timestamp  \
# 0       1      804     4.0  964980499
# 1       1     1210     5.0  964980499
# 2       1     2018     5.0  964980523
# 3       1     2628     4.0  964980523
# 4       1     2826     4.0  964980523
#
#                                                title                    genres
# 0                               She's the One (1996)            Comedy|Romance
# 1  Star Wars: Episode VI - Return of the Jedi (1983)   Action|Adventure|Sci-Fi
# 2                                       Bambi (1942)  Animation|Children|Drama
# 3   Star Wars: Episode I - The Phantom Menace (1999)   Action|Adventure|Sci-Fi
# 4                           13th Warrior, The (1999)  Action|Adventure|Fantasy

# %%
mvlist=data.groupby('userId')['title'].apply(list)

# %%
sequences=list(mvlist)

# %%
voc_data=data.groupby(by='title').count().sort_values(by='userId',ascending=False)

# %%
voc_data
# Out:
#                                   userId  movieId  rating  timestamp  genres
# title
# Shawshank Redemption, The (1994)     289      289     289        289     289
# Forrest Gump (1994)                  276      276     276        276     276
# Pulp Fiction (1994)                  256      256     256        256     256
# Matrix, The (1999)                   240      240     240        240     240
# Silence of the Lambs, The (1991)     239      239     239        239     239
# ...                                  ...      ...     ...        ...     ...
# Honey (Miele) (2013)                   1        1       1          1       1
# Honey (2003)                           1        1       1          1       1
# Home for the Holidays (1995)           1        1       1          1       1
# Home Alone 3 (1997)                    1        1       1          1       1
# '71 (2014)                             1        1       1          1       1
#
# [7359 rows x 5 columns]

# %%
voc_index={}
index_voc={}
i=0
for movie in list(voc_data.index):
    voc_index[movie]=i
    index_voc[i]=movie
    i+=1

# %%
voc_index
# Out:
# {'Shawshank Redemption, The (1994)': 0,
#  'Forrest Gump (1994)': 1,
#  'Pulp Fiction (1994)': 2,
#  'Matrix, The (1999)': 3,
#  'Silence of the Lambs, The (1991)': 4,
#  'Star Wars: Episode IV - A New Hope (1977)': 5,
#  'Fight Club (1999)': 6,
#  "Schindler's List (1993)": 7,
#  'Braveheart (1995)': 8,
#  'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)': 9,
#  'Star Wars: Episode V - The Empire Strikes Back (1980)': 10,
#  'American Beauty (1999)': 11,
#  'Usual Suspects, The (1995)': 12,
#  'Terminator 2: Judgment Day (1991)': 13,
#  'Lord of the Rings: The Fellowship of the Ring, The (2001)': 14,
#  'Jurassic Park (1993)': 15,
#  'Star Wars: Episode VI - Return of the Jedi (1983)': 16,
#  'Toy Story (1995)': 17,
#  'Godfather, The (1972)': 18,
#  'Saving Private Ryan (1998)': 19,
#  'Lord of the Rings: The Return of the King, The (2003)': 20,
#  'Seven (a.k.a. Se7en) (1995)': 21,
#  'Lord of the Rings: The Two Towers, The (2002)': 22,
#  'Fugitive, The (1993)': 23,
#  'Fargo (1996)': 24,
#  'Back to the Future (1985)': 25,
#  'Apollo 13 (1995)': 26,
#  'Sixth Sense, The (1999)': 27,
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)': 28,
#  'Memento (2000)': 29,
#  'Gladiator (2000)': 30,
#  'Dark Knight, The (2008)': 31,
#  'Shrek (2001)': 32,
#  'Lion King, The (1994)': 33,
#  'Aladdin (1992)': 34,
#  'Princess Bride, The (1987)': 35,
#  'Indiana Jones and the Last Crusade (1989)': 36,
#  'Finding Nemo (2003)': 37,
#  'Inception (2010)': 38,
#  'Eternal Sunshine of the Spotless Mind (2004)': 39,
#  'Alien (1979)': 40,
#  'Monty Python and the Holy Grail (1975)': 41,
#  'Goodfellas (1990)': 42,
#  'Dances with Wolves (1990)': 43,
#  "One Flew Over the Cuckoo's Nest (1975)": 44,
#  'Good Will Hunting (1997)': 45,
#  'American History X (1998)': 46,
#  'Independence Day (a.k.a. ID4) (1996)': 47,
#  'Reservoir Dogs (1992)': 48,
#  'Godfather: Part II, The (1974)': 49,
#  'Pirates of the Caribbean: The Curse of the Black Pearl (2003)': 50,
#  'Groundhog Day (1993)': 51,
#  'Kill Bill: Vol. 1 (2003)': 52,
#  'Terminator, The (1984)': 53,
#  'Monsters, Inc. (2001)': 54,
#  'Die Hard (1988)': 55,
#  'Men in Black (a.k.a. MIB) (1997)': 56,
#  'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)': 57,
#  'Beautiful Mind, A (2001)': 58,
#  'Incredibles, The (2004)': 59,
#  "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)": 60,
#  'Blade Runner (1982)': 61,
#  'Green Mile, The (1999)': 62,
#  'X-Men (2000)': 63,
#  "Ocean's Eleven (2001)": 64,
#  'Truman Show, The (1998)': 65,
#  'Speed (1994)': 66,
#  'Catch Me If You Can (2002)': 67,
#  'Departed, The (2006)': 68,
#  'Aliens (1986)': 69,
#  'Clockwork Orange, A (1971)': 70,
#  'Shining, The (1980)': 71,
#  'Donnie Darko (2001)': 72,
#  'Minority Report (2002)': 73,
#  'Batman Begins (2005)': 74,
#  'WALL·E (2008)': 75,
#  'Bourne Identity, The (2002)': 76,
#  'Mission: Impossible (1996)': 77,
#  'True Lies (1994)': 78,
#  'Apocalypse Now (1979)': 79,
#  'Beauty and the Beast (1991)': 80,
#  'Kill Bill: Vol. 2 (2004)': 81,
#  'Trainspotting (1996)': 82,
#  'Willy Wonka & the Chocolate Factory (1971)': 83,
#  'Up (2009)': 84,
#  'Casablanca (1942)': 85,
#  'E.T. the Extra-Terrestrial (1982)': 86,
#  'Ghostbusters (a.k.a. Ghost Busters) (1984)': 87,
#  "Ferris Bueller's Day Off (1986)": 88,
#  'V for Vendetta (2006)': 89,
#  'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)': 90,
#  'Big Lebowski, The (1998)': 91,
#  'Titanic (1997)': 92,
#  'Full Metal Jacket (1987)': 93,
#  'Spider-Man (2002)': 94,
#  '2001: A Space Odyssey (1968)': 95,
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)': 96,
#  'Batman (1989)': 97,
#  'Taxi Driver (1976)': 98,
#  'Breakfast Club, The (1985)': 99,
#  'Babe (1995)': 100,
#  'L.A. Confidential (1997)': 101,
#  'Fifth Element, The (1997)': 102,
#  'Inglourious Basterds (2009)': 103,
#  'Snatch (2000)': 104,
#  'Clerks (1994)': 105,
#  'Being John Malkovich (1999)': 106,
#  'Prestige, The (2006)': 107,
#  "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)": 108,
#  'Office Space (1999)': 109,
#  'Die Hard: With a Vengeance (1995)': 110,
#  'Rock, The (1996)': 111,
#  'Heat (1995)': 112,
#  'Spirited Away (Sen to Chihiro no kamikakushi) (2001)': 113,
#  'Requiem for a Dream (2000)': 114,
#  'Stand by Me (1986)': 115,
#  'Rear Window (1954)': 116,
#  'Pretty Woman (1990)': 117,
#  'Indiana Jones and the Temple of Doom (1984)': 118,
#  'Mrs. Doubtfire (1993)': 119,
#  'GoldenEye (1995)': 120,
#  'Cast Away (2000)': 121,
#  'Harry Potter and the Prisoner of Azkaban (2004)': 122,
#  'Rain Man (1988)': 123,
#  'Life Is Beautiful (La Vita è bella) (1997)': 124,
#  'Iron Man (2008)': 125,
#  "Monty Python's Life of Brian (1979)": 126,
#  'Jaws (1975)': 127,
#  'As Good as It Gets (1997)': 128,
#  "There's Something About Mary (1998)": 129,
#  'O Brother, Where Art Thou? (2000)': 130,
#  'Shakespeare in Love (1998)': 131,
#  'Ice Age (2002)': 132,
#  'Toy Story 2 (1999)': 133,
#  'City of God (Cidade de Deus) (2002)': 134,
#  'Star Trek: First Contact (1996)': 135,
#  'Gattaca (1997)': 136,
#  'Wizard of Oz, The (1939)': 137,
#  'Stargate (1994)': 138,
#  'Dead Poets Society (1989)': 139,
#  'Almost Famous (2000)': 140,
#  'Hunt for Red October, The (1990)': 141,
#  'Austin Powers: International Man of Mystery (1997)': 142,
#  'Airplane! (1980)': 143,
#  'Star Wars: Episode I - The Phantom Menace (1999)': 144,
#  'Casino Royale (2006)': 145,
#  'Big (1988)': 146,
#  'Mask, The (1994)': 147,
#  'Sin City (2005)': 148,
#  'When Harry Met Sally... (1989)': 149,
#  'Amadeus (1984)': 150,
#  'Dark Knight Rises, The (2012)': 151,
#  'Harry Potter and the Chamber of Secrets (2002)': 152,
#  'Run Lola Run (Lola rennt) (1998)': 153,
#  'Shrek 2 (2004)': 154,
#  'Psycho (1960)': 155,
#  'Four Weddings and a Funeral (1994)': 156,
#  'Crimson Tide (1995)': 157,
#  'Casino (1995)': 158,
#  'Graduate, The (1967)': 159,
#  'Shaun of the Dead (2004)': 160,
#  'Clear and Present Danger (1994)': 161,
#  'Ace Ventura: Pet Detective (1994)': 162,
#  'Nightmare Before Christmas, The (1993)': 163,
#  'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)': 164,
#  'Who Framed Roger Rabbit? (1988)': 165,
#  'Little Miss Sunshine (2006)': 166,
#  'Avatar (2009)': 167,
#  "Pan's Labyrinth (Laberinto del fauno, El) (2006)": 168,
#  'Austin Powers: The Spy Who Shagged Me (1999)': 169,
#  '300 (2007)': 170,
#  'American Pie (1999)': 171,
#  'Jumanji (1995)': 172,
#  'Interview with the Vampire: The Vampire Chronicles (1994)': 173,
#  'Lost in Translation (2003)': 174,
#  'Blues Brothers, The (1980)': 175,
#  'Edward Scissorhands (1990)': 176,
#  'Bourne Ultimatum, The (2007)': 177,
#  'Spider-Man 2 (2004)': 178,
#  'Traffic (2000)': 179,
#  'South Park: Bigger, Longer and Uncut (1999)': 180,
#  'Jerry Maguire (1996)': 181,
#  'Slumdog Millionaire (2008)': 182,
#  'Bourne Supremacy, The (2004)': 183,
#  'Citizen Kane (1941)': 184,
#  'Ghost (1990)': 185,
#  'Scarface (1983)': 186,
#  "Bug's Life, A (1998)": 187,
#  'Django Unchained (2012)': 188,
#  'Big Fish (2003)': 189,
#  'Interstellar (2014)': 190,
#  'Harry Potter and the Goblet of Fire (2005)': 191,
#  'Ratatouille (2007)': 192,
#  'Twister (1996)': 193,
#  'Total Recall (1990)': 194,
#  'Happy Gilmore (1996)': 195,
#  'Shutter Island (2010)': 196,
#  'Young Frankenstein (1974)': 197,
#  'Beetlejuice (1988)': 198,
#  'Game, The (1997)': 199,
#  'Lock, Stock & Two Smoking Barrels (1998)': 200,
#  'Sleepless in Seattle (1993)': 201,
#  'High Fidelity (2000)': 202,
#  'X2: X-Men United (2003)': 203,
#  'This Is Spinal Tap (1984)': 204,
#  'Avengers, The (2012)': 205,
#  'Matrix Reloaded, The (2003)': 206,
#  'Firm, The (1993)': 207,
#  'Chinatown (1974)': 208,
#  'Mary Poppins (1964)': 209,
#  'Meet the Parents (2000)': 210,
#  'Last Samurai, The (2003)': 211,
#  "What's Eating Gilbert Grape (1993)": 212,
#  'Dogma (1999)': 213,
#  'Cool Hand Luke (1967)': 214,
#  'Hangover, The (2009)': 215,
#  'Sting, The (1973)': 216,
#  'Hot Fuzz (2007)': 217,
#  'Contact (1997)': 218,
#  'Fish Called Wanda, A (1988)': 219,
#  'Back to the Future Part II (1989)': 220,
#  'Lethal Weapon (1987)': 221,
#  'Children of Men (2006)': 222,
#  'Untouchables, The (1987)': 223,
#  'Star Trek (2009)': 224,
#  'Platoon (1986)': 225,
#  'Dead Man Walking (1995)': 226,
#  'Royal Tenenbaums, The (2001)': 227,
#  '12 Angry Men (1957)': 228,
#  'District 9 (2009)': 229,
#  'Galaxy Quest (1999)': 230,
#  'Brazil (1985)': 231,
#  'Dumb & Dumber (Dumb and Dumber) (1994)': 232,
#  "King's Speech, The (2010)": 233,
#  'Juno (2007)': 234,
#  'Guardians of the Galaxy (2014)': 235,
#  '28 Days Later (2002)': 236,
#  'While You Were Sleeping (1995)': 237,
#  'Blazing Saddles (1974)': 238,
#  'Toy Story 3 (2010)': 239,
#  'No Country for Old Men (2007)': 240,
#  'Rocky (1976)': 241,
#  'Star Trek: Generations (1994)': 242,
#  'North by Northwest (1959)': 243,
#  'Get Shorty (1995)': 244,
#  'Outbreak (1995)': 245,
#  'Vertigo (1958)': 246,
#  '40-Year-Old Virgin, The (2005)': 247,
#  'Star Wars: Episode III - Revenge of the Sith (2005)': 248,
#  'Birdcage, The (1996)': 249,
#  'Sense and Sensibility (1995)': 250,
#  'Chicken Run (2000)': 251,
#  "Mr. Holland's Opus (1995)": 252,
#  'Love Actually (2003)': 253,
#  'Social Network, The (2010)': 254,
#  "It's a Wonderful Life (1946)": 255,
#  'Raising Arizona (1987)': 256,
#  'Tombstone (1993)': 257,
#  'Ed Wood (1994)': 258,
#  'Bowling for Columbine (2002)': 259,
#  'Clueless (1995)': 260,
#  'Star Wars: Episode II - Attack of the Clones (2002)': 261,
#  'To Kill a Mockingbird (1962)': 262,
#  'Unbreakable (2000)': 263,
#  "Pirates of the Caribbean: Dead Man's Chest (2006)": 264,
#  'Sound of Music, The (1965)': 265,
#  "Bridget Jones's Diary (2001)": 266,
#  'Butch Cassidy and the Sundance Kid (1969)': 267,
#  'Snow White and the Seven Dwarfs (1937)': 268,
#  'Erin Brockovich (2000)': 269,
#  'Leaving Las Vegas (1995)': 270,
#  'Harry Potter and the Half-Blood Prince (2009)': 271,
#  'Dave (1993)': 272,
#  'American President, The (1995)': 273,
#  'Wallace & Gromit: The Wrong Trousers (1993)': 274,
#  'Starship Troopers (1997)': 275,
#  'Back to the Future Part III (1990)': 276,
#  'Sherlock Holmes (2009)': 277,
#  'American Psycho (2000)': 278,
#  'Serenity (2005)': 279,
#  'Philadelphia (1993)': 280,
#  'True Romance (1993)': 281,
#  'Anchorman: The Legend of Ron Burgundy (2004)': 282,
#  'Harry Potter and the Order of the Phoenix (2007)': 283,
#  'Zombieland (2009)': 284,
#  'In the Line of Fire (1993)': 285,
#  'Superbad (2007)': 286,
#  'Christmas Story, A (1983)': 287,
#  'The Martian (2015)': 288,
#  'Mummy, The (1999)': 289,
#  'Close Encounters of the Third Kind (1977)': 290,
#  'Full Monty, The (1997)': 291,
#  'Seven Samurai (Shichinin no samurai) (1954)': 292,
#  'Top Gun (1986)': 293,
#  'Million Dollar Baby (2004)': 294,
#  'Few Good Men, A (1992)': 295,
#  'Annie Hall (1977)': 296,
#  'Italian Job, The (2003)': 297,
#  'Patriot, The (2000)': 298,
#  'How to Train Your Dragon (2010)': 299,
#  'Star Trek II: The Wrath of Khan (1982)': 300,
#  'Army of Darkness (1993)': 301,
#  'Predator (1987)': 302,
#  'Crash (2004)': 303,
#  'Wolf of Wall Street, The (2013)': 304,
#  'Princess Mononoke (Mononoke-hime) (1997)': 305,
#  'Quiz Show (1994)': 306,
#  'Blood Diamond (2006)': 307,
#  'Matrix Revolutions, The (2003)': 308,
#  'Hotel Rwanda (2004)': 309,
#  'Maverick (1994)': 310,
#  'Animal House (1978)': 311,
#  'I Am Legend (2007)': 312,
#  'Some Like It Hot (1959)': 313,
#  'Face/Off (1997)': 314,
#  'Sleepy Hollow (1999)': 315,
#  'The Imitation Game (2014)': 316,
#  'Piano, The (1993)': 317,
#  'Pianist, The (2002)': 318,
#  'Deadpool (2016)': 319,
#  'Fantasia (1940)': 320,
#  'Natural Born Killers (1994)': 321,
#  'School of Rock (2003)': 322,
#  'Training Day (2001)': 323,
#  'Gran Torino (2008)': 324,
#  'Goldfinger (1964)': 325,
#  'Harry Potter and the Deathly Hallows: Part 2 (2011)': 326,
#  'Boondock Saints, The (2000)': 327,
#  'Grand Budapest Hotel, The (2014)': 328,
#  'Adaptation (2002)': 329,
#  'Abyss, The (1989)': 330,
#  'Skyfall (2012)': 331,
#  'I, Robot (2004)': 332,
#  'Mystic River (2003)': 333,
#  'Maltese Falcon, The (1941)': 334,
#  'Blow (2001)': 335,
#  'Mulholland Drive (2001)': 336,
#  'Pi (1998)': 337,
#  'Others, The (2001)': 338,
#  'Planet of the Apes (1968)': 339,
#  'Lawrence of Arabia (1962)': 340,
#  'Edge of Tomorrow (2014)': 341,
#  'Knocked Up (2007)': 342,
#  'Superman (1978)': 343,
#  'Exorcist, The (1973)': 344,
#  'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)': 345,
#  'Wedding Crashers (2005)': 346,
#  'Equilibrium (2002)': 347,
#  'Spaceballs (1987)': 348,
#  'Waterworld (1995)': 349,
#  'Magnolia (1999)': 350,
#  'Black Hawk Down (2001)': 351,
#  'Enemy of the State (1998)': 352,
#  'Election (1999)': 353,
#  'Pleasantville (1998)': 354,
#  'Die Hard 2 (1990)': 355,
#  'Moulin Rouge (2001)': 356,
#  'Mars Attacks! (1996)': 357,
#  'Home Alone (1990)': 358,
#  "Singin' in the Rain (1952)": 359,
#  'Dark City (1998)': 360,
#  'Unforgiven (1992)': 361,
#  'Caddyshack (1980)': 362,
#  'X-Men: First Class (2011)': 363,
#  'Net, The (1995)': 364,
#  "Pirates of the Caribbean: At World's End (2007)": 365,
#  'Bridge on the River Kwai, The (1957)': 366,
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)': 367,
#  'Blue Velvet (1986)': 368,
#  'Great Escape, The (1963)': 369,
#  'Desperado (1995)': 370,
#  'Little Mermaid, The (1989)': 371,
#  'Kung Fu Panda (2008)': 372,
#  'Wallace & Gromit: A Close Shave (1995)': 373,
#  'Chicago (2002)': 374,
#  'RoboCop (1987)': 375,
#  'Jungle Book, The (1967)': 376,
#  'In Bruges (2008)': 377,
#  'The Hunger Games (2012)': 378,
#  'Harry Potter and the Deathly Hallows: Part 1 (2010)': 379,
#  'Watchmen (2009)': 380,
#  "Wayne's World (1992)": 381,
#  'Glory (1989)': 382,
#  'Legends of the Fall (1994)': 383,
#  'The Butterfly Effect (2004)': 384,
#  'Stranger than Fiction (2006)': 385,
#  'Best in Show (2000)': 386,
#  'About a Boy (2002)': 387,
#  'Bruce Almighty (2003)': 388,
#  'From Dusk Till Dawn (1996)': 389,
#  'Jackie Brown (1997)': 390,
#  'Donnie Brasco (1997)': 391,
#  'Grosse Pointe Blank (1997)': 392,
#  'M*A*S*H (a.k.a. MASH) (1970)': 393,
#  'Super Size Me (2004)': 394,
#  'Garden State (2004)': 395,
#  'Misery (1990)': 396,
#  'Into the Wild (2007)': 397,
#  'Thing, The (1982)': 398,
#  'Star Wars: Episode VII - The Force Awakens (2015)': 399,
#  'Chasing Amy (1997)': 400,
#  'Simpsons Movie, The (2007)': 401,
#  'My Big Fat Greek Wedding (2002)': 402,
#  'Goonies, The (1985)': 403,
#  'Santa Clause, The (1994)': 404,
#  'Gangs of New York (2002)': 405,
#  'Crow, The (1994)': 406,
#  'Fear and Loathing in Las Vegas (1998)': 407,
#  'Notting Hill (1999)': 408,
#  'Armageddon (1998)': 409,
#  'Boot, Das (Boat, The) (1981)': 410,
#  'Pinocchio (1940)': 411,
#  'Sling Blade (1996)': 412,
#  'Rushmore (1998)': 413,
#  "Howl's Moving Castle (Hauru no ugoku shiro) (2004)": 414,
#  'Blade (1998)': 415,
#  'Scream (1996)': 416,
#  'Raging Bull (1980)': 417,
#  'Pursuit of Happyness, The (2006)': 418,
#  'Inside Out (2015)': 419,
#  'Big Hero 6 (2014)': 420,
#  'Signs (2002)': 421,
#  'Boogie Nights (1997)': 422,
#  'Mad Max: Fury Road (2015)': 423,
#  'Black Swan (2010)': 424,
#  '10 Things I Hate About You (1999)': 425,
#  '50 First Dates (2004)': 426,
#  'Tommy Boy (1995)': 427,
#  "Monty Python's The Meaning of Life (1983)": 428,
#  'Illusionist, The (2006)': 429,
#  'Highlander (1986)': 430,
#  'Collateral (2004)': 431,
#  'Walk the Line (2005)': 432,
#  'Legally Blonde (2001)': 433,
#  'City of Lost Children, The (Cité des enfants perdus, La) (1995)': 434,
#  'The Machinist (2004)': 435,
#  'Dog Day Afternoon (1975)': 436,
#  'Old Boy (2003)': 437,
#  'Iron Man 2 (2010)': 438,
#  'Iron Giant, The (1999)': 439,
#  'Kick-Ass (2010)': 440,
#  'My Neighbor Totoro (Tonari no Totoro) (1988)': 441,
#  'Mr. & Mrs. Smith (2005)': 442,
#  'Three Kings (1999)': 443,
#  'Thomas Crown Affair, The (1999)': 444,
#  'Kingsman: The Secret Service (2015)': 445,
#  'Field of Dreams (1989)': 446,
#  'Billy Elliot (2000)': 447,
#  'Grease (1978)': 448,
#  'Kiss Kiss Bang Bang (2005)': 449,
#  'Dazed and Confused (1993)': 450,
#  'American Graffiti (1973)': 451,
#  'Whiplash (2014)': 452,
#  'Lives of Others, The (Das leben der Anderen) (2006)': 453,
#  '(500) Days of Summer (2009)': 454,
#  'Zoolander (2001)': 455,
#  'American Gangster (2007)': 456,
#  'Demolition Man (1993)': 457,
#  'Wedding Singer, The (1998)': 458,
#  'Remember the Titans (2000)': 459,
#  'Batman Forever (1995)': 460,
#  'Road to Perdition (2002)': 461,
#  'X-Men: The Last Stand (2006)': 462,
#  'Fistful of Dollars, A (Per un pugno di dollari) (1964)': 463,
#  'Gone in 60 Seconds (2000)': 464,
#  'Lady and the Tramp (1955)': 465,
#  'Corpse Bride (2005)': 466,
#  'Labyrinth (1986)': 467,
#  'Sixteen Candles (1984)': 468,
#  'Sherlock Holmes: A Game of Shadows (2011)': 469,
#  'Birds, The (1963)': 470,
#  'Lucky Number Slevin (2006)': 471,
#  'A.I. Artificial Intelligence (2001)': 472,
#  'Femme Nikita, La (Nikita) (1990)': 473,
#  'Deer Hunter, The (1978)': 474,
#  'Hobbit: An Unexpected Journey, The (2012)': 475,
#  "Bill & Ted's Excellent Adventure (1989)": 476,
#  'Mulan (1998)': 477,
#  'Little Women (1994)': 478,
#  'Thank You for Smoking (2006)': 479,
#  'Scott Pilgrim vs. the World (2010)': 480,
#  'Rocky Horror Picture Show, The (1975)': 481,
#  'Inside Man (2006)': 482,
#  'Hurt Locker, The (2008)': 483,
#  'Mean Girls (2004)': 484,
#  'Romancing the Stone (1984)': 485,
#  'Much Ado About Nothing (1993)': 486,
#  'My Fair Lady (1964)': 487,
#  "Carlito's Way (1993)": 488,
#  'Hero (Ying xiong) (2002)': 489,
#  'Akira (1988)': 490,
#  'Good Morning, Vietnam (1987)': 491,
#  'For a Few Dollars More (Per qualche dollaro in più) (1965)': 492,
#  'Eyes Wide Shut (1999)': 493,
#  'Talented Mr. Ripley, The (1999)': 494,
#  'Intouchables (2011)': 495,
#  'Mask of Zorro, The (1998)': 496,
#  'Road Warrior, The (Mad Max 2) (1981)': 497,
#  'French Connection, The (1971)': 498,
#  'Robin Hood: Men in Tights (1993)': 499,
#  'Forgetting Sarah Marshall (2008)': 500,
#  'Hook (1991)': 501,
#  'Bonnie and Clyde (1967)': 502,
#  "Hitchhiker's Guide to the Galaxy, The (2005)": 503,
#  'Truth About Cats & Dogs, The (1996)': 504,
#  'Chocolat (2000)': 505,
#  'Despicable Me (2010)': 506,
#  'Searching for Bobby Fischer (1993)': 507,
#  'Time Bandits (1981)': 508,
#  'English Patient, The (1996)': 509,
#  'Poltergeist (1982)': 510,
#  'Cinema Paradiso (Nuovo cinema Paradiso) (1989)': 511,
#  'Ace Ventura: When Nature Calls (1995)': 512,
#  "Rosemary's Baby (1968)": 513,
#  'Postman, The (Postino, Il) (1994)': 514,
#  'Liar Liar (1997)': 515,
#  'Pocahontas (1995)': 516,
#  'Girl with the Dragon Tattoo, The (2011)': 517,
#  'Elf (2003)': 518,
#  'Go (1999)': 519,
#  'War of the Worlds (2005)': 520,
#  'Dirty Dozen, The (1967)': 521,
#  'Manhattan (1979)': 522,
#  'Beverly Hills Cop (1984)': 523,
#  'Gone Girl (2014)': 524,
#  'Evil Dead II (Dead by Dawn) (1987)': 525,
#  'Terminal, The (2004)': 526,
#  "Breakfast at Tiffany's (1961)": 527,
#  'Curious Case of Benjamin Button, The (2008)': 528,
#  'Sideways (2004)': 529,
#  'Pitch Black (2000)': 530,
#  'Troy (2004)': 531,
#  'Broken Arrow (1996)': 532,
#  "The Devil's Advocate (1997)": 533,
#  'Rounders (1998)': 534,
#  'Charlie and the Chocolate Factory (2005)': 535,
#  'Taken (2008)': 536,
#  'Dodgeball: A True Underdog Story (2004)': 537,
#  'NeverEnding Story, The (1984)': 538,
#  'Master and Commander: The Far Side of the World (2003)': 539,
#  'Miss Congeniality (2000)': 540,
#  'Fast Times at Ridgemont High (1982)': 541,
#  'Blair Witch Project, The (1999)': 542,
#  'Ben-Hur (1959)': 543,
#  'Crazy, Stupid, Love. (2011)': 544,
#  'Adventures of Priscilla, Queen of the Desert, The (1994)': 545,
#  'African Queen, The (1951)': 546,
#  'Vanilla Sky (2001)': 547,
#  'Fahrenheit 9/11 (2004)': 548,
#  'Say Anything... (1989)': 549,
#  'Zodiac (2007)': 550,
#  'Trading Places (1983)': 551,
#  'What Women Want (2000)': 552,
#  'Sneakers (1992)': 553,
#  'Lord of War (2005)': 554,
#  'Manchurian Candidate, The (1962)': 555,
#  'Producers, The (1968)': 556,
#  'Heathers (1989)': 557,
#  'Moon (2009)': 558,
#  'Matchstick Men (2003)': 559,
#  'League of Their Own, A (1992)': 560,
#  'My Cousin Vinny (1992)': 561,
#  'Wrestler, The (2008)': 562,
#  'Last of the Mohicans, The (1992)': 563,
#  "Emperor's New Groove, The (2000)": 564,
#  'Whole Nine Yards, The (2000)': 565,
#  'Client, The (1994)': 566,
#  "You've Got Mail (1998)": 567,
#  'Gone with the Wind (1939)': 568,
#  'Notebook, The (2004)': 569,
#  'Patton (1970)': 570,
#  'Ring, The (2002)': 571,
#  'The Count of Monte Cristo (2002)': 572,
#  'Air Force One (1997)': 573,
#  'Star Trek IV: The Voyage Home (1986)': 574,
#  'Disclosure (1994)': 575,
#  'Swingers (1996)': 576,
#  'Crocodile Dundee (1986)': 577,
#  'Addams Family Values (1993)': 578,
#  'Player, The (1992)': 579,
#  "Boys Don't Cry (1999)": 580,
#  'Philadelphia Story, The (1940)': 581,
#  'Austin Powers in Goldmember (2002)': 582,
#  "All the President's Men (1976)": 583,
#  'The Lego Movie (2014)': 584,
#  'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)': 585,
#  'Coraline (2009)': 586,
#  'Cliffhanger (1993)': 587,
#  'Drive (2011)': 588,
#  'Battle Royale (Batoru rowaiaru) (2000)': 589,
#  'Nutty Professor, The (1996)': 590,
#  'Dirty Dancing (1987)': 591,
#  'Don Juan DeMarco (1995)': 592,
#  'Ghost in the Shell (Kôkaku kidôtai) (1995)': 593,
#  'Witness (1985)': 594,
#  'Da Vinci Code, The (2006)': 595,
#  'Finding Neverland (2004)': 596,
#  'Ronin (1998)': 597,
#  'Splash (1984)': 598,
#  'Enemy at the Gates (2001)': 599,
#  'Rumble in the Bronx (Hont faan kui) (1995)': 600,
#  'Devil Wears Prada, The (2006)': 601,
#  '101 Dalmatians (One Hundred and One Dalmatians) (1961)': 602,
#  'Man on Fire (2004)': 603,
#  'Source Code (2011)': 604,
#  'Hunchback of Notre Dame, The (1996)': 605,
#  'Dune (1984)': 606,
#  'Time to Kill, A (1996)': 607,
#  'Big Daddy (1999)': 608,
#  'Mystery Science Theater 3000: The Movie (1996)': 609,
#  'Con Air (1997)': 610,
#  'King Kong (2005)': 611,
#  'Old School (2003)': 612,
#  'Aviator, The (2004)': 613,
#  'Bad Boys (1995)': 614,
#  'Rob Roy (1995)': 615,
#  'Arsenic and Old Lace (1944)': 616,
#  'Zootopia (2016)': 617,
#  'Insider, The (1999)': 618,
#  'Karate Kid, The (1984)': 619,
#  'Aristocats, The (1970)': 620,
#  'Billy Madison (1995)': 621,
#  '8 Mile (2002)': 622,
#  'Stardust (2007)': 623,
#  'Blind Side, The  (2009)': 624,
#  'Star Trek VI: The Undiscovered Country (1991)': 625,
#  'Mad Max (1979)': 626,
#  'Peter Pan (1953)': 627,
#  'Limitless (2011)': 628,
#  "Monty Python's And Now for Something Completely Different (1971)": 629,
#  'Roger & Me (1989)': 630,
#  'Up in the Air (2009)': 631,
#  'Hoop Dreams (1994)': 632,
#  'Grand Day Out with Wallace and Gromit, A (1989)': 633,
#  'X-Files: Fight the Future, The (1998)': 634,
#  'Hellboy (2004)': 635,
#  'Killing Fields, The (1984)': 636,
#  'Lilo & Stitch (2002)': 637,
#  'National Treasure (2004)': 638,
#  'Naked Gun: From the Files of Police Squad!, The (1988)': 639,
#  "My Best Friend's Wedding (1997)": 640,
#  'Three Musketeers, The (1993)': 641,
#  'Mummy Returns, The (2001)': 642,
#  'Cars (2006)': 643,
#  'There Will Be Blood (2007)': 644,
#  'Thelma & Louise (1991)': 645,
#  'James and the Giant Peach (1996)': 646,
#  'Payback (1999)': 647,
#  'Argo (2012)': 648,
#  'Do the Right Thing (1989)': 649,
#  'Deliverance (1972)': 650,
#  'Captain America: The Winter Soldier (2014)': 651,
#  'Eraser (1996)': 652,
#  "William Shakespeare's Romeo + Juliet (1996)": 653,
#  'Mallrats (1995)': 654,
#  'Easy A (2010)': 655,
#  'Guardians of the Galaxy 2 (2017)': 656,
#  'Harold and Maude (1971)': 657,
#  'Bend It Like Beckham (2002)': 658,
#  'Life of Pi (2012)': 659,
#  'Yes Man (2008)': 660,
#  'Quantum of Solace (2008)': 661,
#  'X-Men: Days of Future Past (2014)': 662,
#  'October Sky (1999)': 663,
#  'Muppet Movie, The (1979)': 664,
#  'Dial M for Murder (1954)': 665,
#  'Thor (2011)': 666,
#  'I.Q. (1994)': 667,
#  'Logan (2017)': 668,
#  'Batman Returns (1992)': 669,
#  'First Knight (1995)': 670,
#  'Mission: Impossible II (2000)': 671,
#  'John Wick (2014)': 672,
#  'Stripes (1981)': 673,
#  'Fisher King, The (1991)': 674,
#  'Silver Linings Playbook (2012)': 675,
#  'American Pie 2 (2001)': 676,
#  "Charlie's Angels (2000)": 677,
#  'Grumpier Old Men (1995)': 678,
#  'Harold and Kumar Go to White Castle (2004)': 679,
#  'Risky Business (1983)': 680,
#  'Tron (1982)': 681,
#  'Gremlins (1984)': 682,
#  'In the Name of the Father (1993)': 683,
#  'Out of Sight (1998)': 684,
#  'Dark Crystal, The (1982)': 685,
#  'Sabrina (1954)': 686,
#  'Sabrina (1995)': 687,
#  'Man on the Moon (1999)': 688,
#  'Captain America: The First Avenger (2011)': 689,
#  'Madagascar (2005)': 690,
#  "Ocean's Twelve (2004)": 691,
#  'All About Eve (1950)': 692,
#  'Big Trouble in Little China (1986)': 693,
#  'Shanghai Noon (2000)': 694,
#  'Fly, The (1986)': 695,
#  'So I Married an Axe Murderer (1993)': 696,
#  'Hudsucker Proxy, The (1994)': 697,
#  'Ex Machina (2015)': 698,
#  'Moneyball (2011)': 699,
#  'Rush Hour (1998)': 700,
#  'Cocoon (1985)': 701,
#  'Sweeney Todd: The Demon Barber of Fleet Street (2007)': 702,
#  'From Russia with Love (1963)': 703,
#  'Dr. No (1962)': 704,
#  'Apartment, The (1960)': 705,
#  'Crying Game, The (1992)': 706,
#  'Babel (2006)': 707,
#  'Wallace & Gromit: The Best of Aardman Animation (1996)': 708,
#  'Naked Gun 33 1/3: The Final Insult (1994)': 709,
#  'The Revenant (2015)': 710,
#  'French Kiss (1995)': 711,
#  'Godfather: Part III, The (1990)': 712,
#  'Like Water for Chocolate (Como agua para chocolate) (1992)': 713,
#  'Bull Durham (1988)': 714,
#  'Moonrise Kingdom (2012)': 715,
#  'Dragonheart (1996)': 716,
#  'Burn After Reading (2008)': 717,
#  'Transformers (2007)': 718,
#  'Alice in Wonderland (1951)': 719,
#  'Me, Myself & Irene (2000)': 720,
#  "Knight's Tale, A (2001)": 721,
#  'Brokeback Mountain (2005)': 722,
#  'Ghost World (2001)': 723,
#  '3:10 to Yuma (2007)': 724,
#  'Lethal Weapon 2 (1989)': 725,
#  'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)': 726,
#  'Little Shop of Horrors (1986)': 727,
#  'Kingpin (1996)': 728,
#  'Frozen (2013)': 729,
#  'Hitch (2005)': 730,
#  'Little Big Man (1970)': 731,
#  'Life Aquatic with Steve Zissou, The (2004)': 732,
#  'Looper (2012)': 733,
#  'Hercules (1997)': 734,
#  'Gandhi (1982)': 735,
#  'Phenomenon (1996)': 736,
#  'Cruel Intentions (1999)': 737,
#  'Town, The (2010)': 738,
#  'Star Trek III: The Search for Spock (1984)': 739,
#  'Tropic Thunder (2008)': 740,
#  'True Grit (2010)': 741,
#  'Alien³ (a.k.a. Alien 3) (1992)': 742,
#  'Emma (1996)': 743,
#  'Team America: World Police (2004)': 744,
#  'On the Waterfront (1954)': 745,
#  'To Catch a Thief (1955)': 746,
#  'Dangerous Liaisons (1988)': 747,
#  'Primal Fear (1996)': 748,
#  'Punch-Drunk Love (2002)': 749,
#  'Motorcycle Diaries, The (Diarios de motocicleta) (2004)': 750,
#  'Easy Rider (1969)': 751,
#  'Shine (1996)': 752,
#  'Perfect Storm, The (2000)': 753,
#  'Capote (2005)': 754,
#  'Pineapple Express (2008)': 755,
#  'Rogue One: A Star Wars Story (2016)': 756,
#  'Madness of King George, The (1994)': 757,
#  'Willow (1988)': 758,
#  'Ant-Man (2015)': 759,
#  'Arrival (2016)': 760,
#  'Secretary (2002)': 761,
#  'Cinderella (1950)': 762,
#  'Tangled (2010)': 763,
#  'Third Man, The (1949)': 764,
#  'Frequency (2000)': 765,
#  'Terminator 3: Rise of the Machines (2003)': 766,
#  'The Hunger Games: Mockingjay - Part 1 (2014)': 767,
#  'The Hunger Games: Catching Fire (2013)': 768,
#  'Spider-Man 3 (2007)': 769,
#  'Pride & Prejudice (2005)': 770,
#  'Strangers on a Train (1951)': 771,
#  'JFK (1991)': 772,
#  'Bambi (1942)': 773,
#  'Finding Forrester (2000)': 774,
#  "Dr. Horrible's Sing-Along Blog (2008)": 775,
#  'Sleepers (1996)': 776,
#  'Sleeper (1973)': 777,
#  'Planes, Trains & Automobiles (1987)': 778,
#  'Day After Tomorrow, The (2004)': 779,
#  'Doors, The (1991)': 780,
#  'Roman Holiday (1953)': 781,
#  'Lost World: Jurassic Park, The (1997)': 782,
#  'Napoleon Dynamite (2004)': 783,
#  'Island, The (2005)': 784,
#  'Waking Ned Devine (a.k.a. Waking Ned) (1998)': 785,
#  'Antz (1998)': 786,
#  'Before Sunrise (1995)': 787,
#  'Tootsie (1982)': 788,
#  'Gravity (2013)': 789,
#  'World Is Not Enough, The (1999)': 790,
#  "Christmas Vacation (National Lampoon's Christmas Vacation) (1989)": 791,
#  'Mission: Impossible III (2006)': 792,
#  'Mystery Men (1999)': 793,
#  'Basic Instinct (1992)': 794,
#  'Tin Cup (1996)': 795,
#  'Carrie (1976)': 796,
#  'Road Trip (2000)': 797,
#  'Underworld (2003)': 798,
#  'Three Colors: Blue (Trois couleurs: Bleu) (1993)': 799,
#  'Escape from New York (1981)': 800,
#  'Iron Man 3 (2013)': 801,
#  'K-PAX (2001)': 802,
#  '21 Jump Street (2012)': 803,
#  'Wallace & Gromit in The Curse of the Were-Rabbit (2005)': 804,
#  'Shooter (2007)': 805,
#  'Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)': 806,
#  'West Side Story (1961)': 807,
#  'Dumbo (1941)': 808,
#  'Hot Shots! Part Deux (1993)': 809,
#  'House of Flying Daggers (Shi mian mai fu) (2004)': 810,
#  'Rise of the Planet of the Apes (2011)': 811,
#  'Jay and Silent Bob Strike Back (2001)': 812,
#  'Pearl Harbor (2001)': 813,
#  'Jungle Book, The (1994)': 814,
#  'People vs. Larry Flynt, The (1996)': 815,
#  'Saw (2004)': 816,
#  'Cider House Rules, The (1999)': 817,
#  'U-571 (2000)': 818,
#  'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)': 819,
#  'Notorious (1946)': 820,
#  'Thin Red Line, The (1998)': 821,
#  'Brave (2012)': 822,
#  'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)': 823,
#  'Network (1976)': 824,
#  'Modern Times (1936)': 825,
#  'Bound (1996)': 826,
#  'Final Fantasy: The Spirits Within (2001)': 827,
#  'Star Trek Into Darkness (2013)': 828,
#  'Transporter, The (2002)': 829,
#  "Ocean's Thirteen (2007)": 830,
#  'Heavy Metal (1981)': 831,
#  'Gosford Park (2001)': 832,
#  'Executive Decision (1996)': 833,
#  'Big Short, The (2015)': 834,
#  'Incredible Hulk, The (2008)': 835,
#  'Cell, The (2000)': 836,
#  'Robin Hood (1973)': 837,
#  'Return of the Pink Panther, The (1975)': 838,
#  'Rudy (1993)': 839,
#  'Lost Boys, The (1987)': 840,
#  'Scary Movie (2000)': 841,
#  'Scent of a Woman (1992)': 842,
#  'eXistenZ (1999)': 843,
#  'Wreck-It Ralph (2012)': 844,
#  'Gods Must Be Crazy, The (1980)': 845,
#  '25th Hour (2002)': 846,
#  'Virgin Suicides, The (1999)': 847,
#  'Tomorrow Never Dies (1997)': 848,
#  'Three Colors: White (Trzy kolory: Bialy) (1994)': 849,
#  'Grifters, The (1990)': 850,
#  'Constantine (2005)': 851,
#  'Fried Green Tomatoes (1991)': 852,
#  'Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku no Tobira) (2001)': 853,
#  'Fighter, The (2010)': 854,
#  'Streetcar Named Desire, A (1951)': 855,
#  'Cube (1997)': 856,
#  'Help, The (2011)': 857,
#  'Her (2013)': 858,
#  'Honey, I Shrunk the Kids (1989)': 859,
#  'Hoosiers (a.k.a. Best Shot) (1986)': 860,
#  'Day the Earth Stood Still, The (1951)': 861,
#  "Amores Perros (Love's a Bitch) (2000)": 862,
#  'Analyze This (1999)': 863,
#  'Red Dragon (2002)': 864,
#  'First Blood (Rambo: First Blood) (1982)': 865,
#  'Driving Miss Daisy (1989)': 866,
#  'Doctor Zhivago (1965)': 867,
#  'Entrapment (1999)': 868,
#  'Cape Fear (1991)': 869,
#  'Live Free or Die Hard (2007)': 870,
#  "Miller's Crossing (1990)": 871,
#  'Lara Croft: Tomb Raider (2001)': 872,
#  "National Lampoon's Vacation (1983)": 873,
#  'Nell (1994)': 874,
#  'Night of the Living Dead (1968)': 875,
#  'Panic Room (2002)': 876,
#  'Patriot Games (1992)': 877,
#  'Avengers: Age of Ultron (2015)': 878,
#  "Jacob's Ladder (1990)": 879,
#  'Last Emperor, The (1987)': 880,
#  'Casper (1995)': 881,
#  'Deep Impact (1998)': 882,
#  'Waiting for Guffman (1996)': 883,
#  'Bullets Over Broadway (1994)': 884,
#  'Superman II (1980)': 885,
#  'Captain Phillips (2013)': 886,
#  'And Your Mother Too (Y tu mamá también) (2001)': 887,
#  'Dancer in the Dark (2000)': 888,
#  'Delicatessen (1991)': 889,
#  'Dangerous Minds (1995)': 890,
#  'Bad Santa (2003)': 891,
#  '28 Weeks Later (2007)': 892,
#  'Eastern Promises (2007)': 893,
#  'Addams Family, The (1991)': 894,
#  'Patch Adams (1998)': 895,
#  "Muriel's Wedding (1994)": 896,
#  'Amazing Spider-Man, The (2012)': 897,
#  'Big Chill, The (1983)': 898,
#  'Hobbit: The Desolation of Smaug, The (2013)': 899,
#  'Downfall (Untergang, Der) (2004)': 900,
#  'Fatal Attraction (1987)': 901,
#  'All About My Mother (Todo sobre mi madre) (1999)': 902,
#  'Meet the Fockers (2004)': 903,
#  'Ransom (1996)': 904,
#  'Cinderella Man (2005)': 905,
#  'Step Brothers (2008)': 906,
#  'Duck Soup (1933)': 907,
#  'Right Stuff, The (1983)': 908,
#  'Dogville (2003)': 909,
#  'Cabin in the Woods, The (2012)': 910,
#  'Bottle Rocket (1996)': 911,
#  'Spotlight (2015)': 912,
#  'Matilda (1996)': 913,
#  'Last King of Scotland, The (2006)': 914,
#  "Dracula (Bram Stoker's Dracula) (1992)": 915,
#  'Girl, Interrupted (1999)': 916,
#  'Little Princess, A (1995)': 917,
#  'Phone Booth (2002)': 918,
#  'Swordfish (2001)': 919,
#  'Fast and the Furious, The (2001)': 920,
#  'Cable Guy, The (1996)': 921,
#  'Professional, The (Le professionnel) (1981)': 922,
#  'Negotiator, The (1998)': 923,
#  'Natural, The (1984)': 924,
#  'Red Violin, The (Violon rouge, Le) (1998)': 925,
#  'Crumb (1994)': 926,
#  'Nightcrawler (2014)': 927,
#  'Star Trek: The Motion Picture (1979)': 928,
#  'Crimes and Misdemeanors (1989)': 929,
#  'Sword in the Stone, The (1963)': 930,
#  'Layer Cake (2004)': 931,
#  'Thor: Ragnarok (2017)': 932,
#  'Long Kiss Goodnight, The (1996)': 933,
#  'Zack and Miri Make a Porno (2008)': 934,
#  'Lone Star (1996)': 935,
#  'Evil Dead, The (1981)': 936,
#  'Escape from L.A. (1996)': 937,
#  'Rashomon (Rashômon) (1950)': 938,
#  'Wonder Boys (2000)': 939,
#  'Ghostbusters II (1989)': 940,
#  'What About Bob? (1991)': 941,
#  "We're the Millers (2013)": 942,
#  'Better Off Dead... (1985)': 943,
#  'Bridesmaids (2011)': 944,
#  'Beach, The (2000)': 945,
#  'Good Night, and Good Luck. (2005)': 946,
#  'Good bye, Lenin! (2003)': 947,
#  'Metropolis (1927)': 948,
#  'Elizabeth (1998)': 949,
#  'Midnight Cowboy (1969)': 950,
#  'Triplets of Belleville, The (Les triplettes de Belleville) (2003)': 951,
#  'Midnight in Paris (2011)': 952,
#  'Moonstruck (1987)': 953,
#  'Star Trek: Insurrection (1998)': 954,
#  'Munich (2005)': 955,
#  'Grindhouse (2007)': 956,
#  'Conspiracy Theory (1997)': 957,
#  'Congo (1995)': 958,
#  'Ray (2004)': 959,
#  'History of Violence, A (2005)': 960,
#  'Identity (2003)': 961,
#  'Kids (1995)': 962,
#  'Double Indemnity (1944)': 963,
#  'Secret Life of Walter Mitty, The (2013)': 964,
#  'Role Models (2008)': 965,
#  'Rush Hour 2 (2001)': 966,
#  'Pink Floyd: The Wall (1982)': 967,
#  'Dirty Harry (1971)': 968,
#  'Simple Plan, A (1998)': 969,
#  'Scanner Darkly, A (2006)': 970,
#  'Pitch Perfect (2012)': 971,
#  'Awakenings (1990)': 972,
#  'Outlaw Josey Wales, The (1976)': 973,
#  'Planet Terror (2007)': 974,
#  'Death Proof (2007)': 975,
#  'Sliding Doors (1998)': 976,
#  'Horrible Bosses (2011)': 977,
#  'Boiler Room (2000)': 978,
#  'High Noon (1952)': 979,
#  "Once Upon a Time in the West (C'era una volta il West) (1968)": 980,
#  'Hustler, The (1961)': 981,
#  'Henry V (1989)': 982,
#  'Pay It Forward (2000)': 983,
#  'Hellboy II: The Golden Army (2008)': 984,
#  'Alien: Resurrection (1997)': 985,
#  'River Wild, The (1994)': 986,
#  'River Runs Through It, A (1992)': 987,
#  'Private Parts (1997)': 988,
#  'Seventh Seal, The (Sjunde inseglet, Det) (1957)': 989,
#  'Megamind (2010)': 990,
#  'Anger Management (2003)': 991,
#  'Now You See Me (2013)': 992,
#  'Wall Street (1987)': 993,
#  'I Heart Huckabees (2004)': 994,
#  'Johnny Mnemonic (1995)': 995,
#  'Wag the Dog (1997)': 996,
#  'Perks of Being a Wallflower, The (2012)': 997,
#  'Untitled Spider-Man Reboot (2017)': 998,
#  'Despicable Me 2 (2013)': 999,
#  ...}

# %%
index_voc
# Out:
# {0: 'Shawshank Redemption, The (1994)',
#  1: 'Forrest Gump (1994)',
#  2: 'Pulp Fiction (1994)',
#  3: 'Matrix, The (1999)',
#  4: 'Silence of the Lambs, The (1991)',
#  5: 'Star Wars: Episode IV - A New Hope (1977)',
#  6: 'Fight Club (1999)',
#  7: "Schindler's List (1993)",
#  8: 'Braveheart (1995)',
#  9: 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)',
#  10: 'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  11: 'American Beauty (1999)',
#  12: 'Usual Suspects, The (1995)',
#  13: 'Terminator 2: Judgment Day (1991)',
#  14: 'Lord of the Rings: The Fellowship of the Ring, The (2001)',
#  15: 'Jurassic Park (1993)',
#  16: 'Star Wars: Episode VI - Return of the Jedi (1983)',
#  17: 'Toy Story (1995)',
#  18: 'Godfather, The (1972)',
#  19: 'Saving Private Ryan (1998)',
#  20: 'Lord of the Rings: The Return of the King, The (2003)',
#  21: 'Seven (a.k.a. Se7en) (1995)',
#  22: 'Lord of the Rings: The Two Towers, The (2002)',
#  23: 'Fugitive, The (1993)',
#  24: 'Fargo (1996)',
#  25: 'Back to the Future (1985)',
#  26: 'Apollo 13 (1995)',
#  27: 'Sixth Sense, The (1999)',
#  28: 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#  29: 'Memento (2000)',
#  30: 'Gladiator (2000)',
#  31: 'Dark Knight, The (2008)',
#  32: 'Shrek (2001)',
#  33: 'Lion King, The (1994)',
#  34: 'Aladdin (1992)',
#  35: 'Princess Bride, The (1987)',
#  36: 'Indiana Jones and the Last Crusade (1989)',
#  37: 'Finding Nemo (2003)',
#  38: 'Inception (2010)',
#  39: 'Eternal Sunshine of the Spotless Mind (2004)',
#  40: 'Alien (1979)',
#  41: 'Monty Python and the Holy Grail (1975)',
#  42: 'Goodfellas (1990)',
#  43: 'Dances with Wolves (1990)',
#  44: "One Flew Over the Cuckoo's Nest (1975)",
#  45: 'Good Will Hunting (1997)',
#  46: 'American History X (1998)',
#  47: 'Independence Day (a.k.a. ID4) (1996)',
#  48: 'Reservoir Dogs (1992)',
#  49: 'Godfather: Part II, The (1974)',
#  50: 'Pirates of the Caribbean: The Curse of the Black Pearl (2003)',
#  51: 'Groundhog Day (1993)',
#  52: 'Kill Bill: Vol. 1 (2003)',
#  53: 'Terminator, The (1984)',
#  54: 'Monsters, Inc. (2001)',
#  55: 'Die Hard (1988)',
#  56: 'Men in Black (a.k.a. MIB) (1997)',
#  57: 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)',
#  58: 'Beautiful Mind, A (2001)',
#  59: 'Incredibles, The (2004)',
#  60: "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)",
#  61: 'Blade Runner (1982)',
#  62: 'Green Mile, The (1999)',
#  63: 'X-Men (2000)',
#  64: "Ocean's Eleven (2001)",
#  65: 'Truman Show, The (1998)',
#  66: 'Speed (1994)',
#  67: 'Catch Me If You Can (2002)',
#  68: 'Departed, The (2006)',
#  69: 'Aliens (1986)',
#  70: 'Clockwork Orange, A (1971)',
#  71: 'Shining, The (1980)',
#  72: 'Donnie Darko (2001)',
#  73: 'Minority Report (2002)',
#  74: 'Batman Begins (2005)',
#  75: 'WALL·E (2008)',
#  76: 'Bourne Identity, The (2002)',
#  77: 'Mission: Impossible (1996)',
#  78: 'True Lies (1994)',
#  79: 'Apocalypse Now (1979)',
#  80: 'Beauty and the Beast (1991)',
#  81: 'Kill Bill: Vol. 2 (2004)',
#  82: 'Trainspotting (1996)',
#  83: 'Willy Wonka & the Chocolate Factory (1971)',
#  84: 'Up (2009)',
#  85: 'Casablanca (1942)',
#  86: 'E.T. the Extra-Terrestrial (1982)',
#  87: 'Ghostbusters (a.k.a. Ghost Busters) (1984)',
#  88: "Ferris Bueller's Day Off (1986)",
#  89: 'V for Vendetta (2006)',
#  90: 'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)',
#  91: 'Big Lebowski, The (1998)',
#  92: 'Titanic (1997)',
#  93: 'Full Metal Jacket (1987)',
#  94: 'Spider-Man (2002)',
#  95: '2001: A Space Odyssey (1968)',
#  96: 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#  97: 'Batman (1989)',
#  98: 'Taxi Driver (1976)',
#  99: 'Breakfast Club, The (1985)',
#  100: 'Babe (1995)',
#  101: 'L.A. Confidential (1997)',
#  102: 'Fifth Element, The (1997)',
#  103: 'Inglourious Basterds (2009)',
#  104: 'Snatch (2000)',
#  105: 'Clerks (1994)',
#  106: 'Being John Malkovich (1999)',
#  107: 'Prestige, The (2006)',
#  108: "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)",
#  109: 'Office Space (1999)',
#  110: 'Die Hard: With a Vengeance (1995)',
#  111: 'Rock, The (1996)',
#  112: 'Heat (1995)',
#  113: 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)',
#  114: 'Requiem for a Dream (2000)',
#  115: 'Stand by Me (1986)',
#  116: 'Rear Window (1954)',
#  117: 'Pretty Woman (1990)',
#  118: 'Indiana Jones and the Temple of Doom (1984)',
#  119: 'Mrs. Doubtfire (1993)',
#  120: 'GoldenEye (1995)',
#  121: 'Cast Away (2000)',
#  122: 'Harry Potter and the Prisoner of Azkaban (2004)',
#  123: 'Rain Man (1988)',
#  124: 'Life Is Beautiful (La Vita è bella) (1997)',
#  125: 'Iron Man (2008)',
#  126: "Monty Python's Life of Brian (1979)",
#  127: 'Jaws (1975)',
#  128: 'As Good as It Gets (1997)',
#  129: "There's Something About Mary (1998)",
#  130: 'O Brother, Where Art Thou? (2000)',
#  131: 'Shakespeare in Love (1998)',
#  132: 'Ice Age (2002)',
#  133: 'Toy Story 2 (1999)',
#  134: 'City of God (Cidade de Deus) (2002)',
#  135: 'Star Trek: First Contact (1996)',
#  136: 'Gattaca (1997)',
#  137: 'Wizard of Oz, The (1939)',
#  138: 'Stargate (1994)',
#  139: 'Dead Poets Society (1989)',
#  140: 'Almost Famous (2000)',
#  141: 'Hunt for Red October, The (1990)',
#  142: 'Austin Powers: International Man of Mystery (1997)',
#  143: 'Airplane! (1980)',
#  144: 'Star Wars: Episode I - The Phantom Menace (1999)',
#  145: 'Casino Royale (2006)',
#  146: 'Big (1988)',
#  147: 'Mask, The (1994)',
#  148: 'Sin City (2005)',
#  149: 'When Harry Met Sally... (1989)',
#  150: 'Amadeus (1984)',
#  151: 'Dark Knight Rises, The (2012)',
#  152: 'Harry Potter and the Chamber of Secrets (2002)',
#  153: 'Run Lola Run (Lola rennt) (1998)',
#  154: 'Shrek 2 (2004)',
#  155: 'Psycho (1960)',
#  156: 'Four Weddings and a Funeral (1994)',
#  157: 'Crimson Tide (1995)',
#  158: 'Casino (1995)',
#  159: 'Graduate, The (1967)',
#  160: 'Shaun of the Dead (2004)',
#  161: 'Clear and Present Danger (1994)',
#  162: 'Ace Ventura: Pet Detective (1994)',
#  163: 'Nightmare Before Christmas, The (1993)',
#  164: 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)',
#  165: 'Who Framed Roger Rabbit? (1988)',
#  166: 'Little Miss Sunshine (2006)',
#  167: 'Avatar (2009)',
#  168: "Pan's Labyrinth (Laberinto del fauno, El) (2006)",
#  169: 'Austin Powers: The Spy Who Shagged Me (1999)',
#  170: '300 (2007)',
#  171: 'American Pie (1999)',
#  172: 'Jumanji (1995)',
#  173: 'Interview with the Vampire: The Vampire Chronicles (1994)',
#  174: 'Lost in Translation (2003)',
#  175: 'Blues Brothers, The (1980)',
#  176: 'Edward Scissorhands (1990)',
#  177: 'Bourne Ultimatum, The (2007)',
#  178: 'Spider-Man 2 (2004)',
#  179: 'Traffic (2000)',
#  180: 'South Park: Bigger, Longer and Uncut (1999)',
#  181: 'Jerry Maguire (1996)',
#  182: 'Slumdog Millionaire (2008)',
#  183: 'Bourne Supremacy, The (2004)',
#  184: 'Citizen Kane (1941)',
#  185: 'Ghost (1990)',
#  186: 'Scarface (1983)',
#  187: "Bug's Life, A (1998)",
#  188: 'Django Unchained (2012)',
#  189: 'Big Fish (2003)',
#  190: 'Interstellar (2014)',
#  191: 'Harry Potter and the Goblet of Fire (2005)',
#  192: 'Ratatouille (2007)',
#  193: 'Twister (1996)',
#  194: 'Total Recall (1990)',
#  195: 'Happy Gilmore (1996)',
#  196: 'Shutter Island (2010)',
#  197: 'Young Frankenstein (1974)',
#  198: 'Beetlejuice (1988)',
#  199: 'Game, The (1997)',
#  200: 'Lock, Stock & Two Smoking Barrels (1998)',
#  201: 'Sleepless in Seattle (1993)',
#  202: 'High Fidelity (2000)',
#  203: 'X2: X-Men United (2003)',
#  204: 'This Is Spinal Tap (1984)',
#  205: 'Avengers, The (2012)',
#  206: 'Matrix Reloaded, The (2003)',
#  207: 'Firm, The (1993)',
#  208: 'Chinatown (1974)',
#  209: 'Mary Poppins (1964)',
#  210: 'Meet the Parents (2000)',
#  211: 'Last Samurai, The (2003)',
#  212: "What's Eating Gilbert Grape (1993)",
#  213: 'Dogma (1999)',
#  214: 'Cool Hand Luke (1967)',
#  215: 'Hangover, The (2009)',
#  216: 'Sting, The (1973)',
#  217: 'Hot Fuzz (2007)',
#  218: 'Contact (1997)',
#  219: 'Fish Called Wanda, A (1988)',
#  220: 'Back to the Future Part II (1989)',
#  221: 'Lethal Weapon (1987)',
#  222: 'Children of Men (2006)',
#  223: 'Untouchables, The (1987)',
#  224: 'Star Trek (2009)',
#  225: 'Platoon (1986)',
#  226: 'Dead Man Walking (1995)',
#  227: 'Royal Tenenbaums, The (2001)',
#  228: '12 Angry Men (1957)',
#  229: 'District 9 (2009)',
#  230: 'Galaxy Quest (1999)',
#  231: 'Brazil (1985)',
#  232: 'Dumb & Dumber (Dumb and Dumber) (1994)',
#  233: "King's Speech, The (2010)",
#  234: 'Juno (2007)',
#  235: 'Guardians of the Galaxy (2014)',
#  236: '28 Days Later (2002)',
#  237: 'While You Were Sleeping (1995)',
#  238: 'Blazing Saddles (1974)',
#  239: 'Toy Story 3 (2010)',
#  240: 'No Country for Old Men (2007)',
#  241: 'Rocky (1976)',
#  242: 'Star Trek: Generations (1994)',
#  243: 'North by Northwest (1959)',
#  244: 'Get Shorty (1995)',
#  245: 'Outbreak (1995)',
#  246: 'Vertigo (1958)',
#  247: '40-Year-Old Virgin, The (2005)',
#  248: 'Star Wars: Episode III - Revenge of the Sith (2005)',
#  249: 'Birdcage, The (1996)',
#  250: 'Sense and Sensibility (1995)',
#  251: 'Chicken Run (2000)',
#  252: "Mr. Holland's Opus (1995)",
#  253: 'Love Actually (2003)',
#  254: 'Social Network, The (2010)',
#  255: "It's a Wonderful Life (1946)",
#  256: 'Raising Arizona (1987)',
#  257: 'Tombstone (1993)',
#  258: 'Ed Wood (1994)',
#  259: 'Bowling for Columbine (2002)',
#  260: 'Clueless (1995)',
#  261: 'Star Wars: Episode II - Attack of the Clones (2002)',
#  262: 'To Kill a Mockingbird (1962)',
#  263: 'Unbreakable (2000)',
#  264: "Pirates of the Caribbean: Dead Man's Chest (2006)",
#  265: 'Sound of Music, The (1965)',
#  266: "Bridget Jones's Diary (2001)",
#  267: 'Butch Cassidy and the Sundance Kid (1969)',
#  268: 'Snow White and the Seven Dwarfs (1937)',
#  269: 'Erin Brockovich (2000)',
#  270: 'Leaving Las Vegas (1995)',
#  271: 'Harry Potter and the Half-Blood Prince (2009)',
#  272: 'Dave (1993)',
#  273: 'American President, The (1995)',
#  274: 'Wallace & Gromit: The Wrong Trousers (1993)',
#  275: 'Starship Troopers (1997)',
#  276: 'Back to the Future Part III (1990)',
#  277: 'Sherlock Holmes (2009)',
#  278: 'American Psycho (2000)',
#  279: 'Serenity (2005)',
#  280: 'Philadelphia (1993)',
#  281: 'True Romance (1993)',
#  282: 'Anchorman: The Legend of Ron Burgundy (2004)',
#  283: 'Harry Potter and the Order of the Phoenix (2007)',
#  284: 'Zombieland (2009)',
#  285: 'In the Line of Fire (1993)',
#  286: 'Superbad (2007)',
#  287: 'Christmas Story, A (1983)',
#  288: 'The Martian (2015)',
#  289: 'Mummy, The (1999)',
#  290: 'Close Encounters of the Third Kind (1977)',
#  291: 'Full Monty, The (1997)',
#  292: 'Seven Samurai (Shichinin no samurai) (1954)',
#  293: 'Top Gun (1986)',
#  294: 'Million Dollar Baby (2004)',
#  295: 'Few Good Men, A (1992)',
#  296: 'Annie Hall (1977)',
#  297: 'Italian Job, The (2003)',
#  298: 'Patriot, The (2000)',
#  299: 'How to Train Your Dragon (2010)',
#  300: 'Star Trek II: The Wrath of Khan (1982)',
#  301: 'Army of Darkness (1993)',
#  302: 'Predator (1987)',
#  303: 'Crash (2004)',
#  304: 'Wolf of Wall Street, The (2013)',
#  305: 'Princess Mononoke (Mononoke-hime) (1997)',
#  306: 'Quiz Show (1994)',
#  307: 'Blood Diamond (2006)',
#  308: 'Matrix Revolutions, The (2003)',
#  309: 'Hotel Rwanda (2004)',
#  310: 'Maverick (1994)',
#  311: 'Animal House (1978)',
#  312: 'I Am Legend (2007)',
#  313: 'Some Like It Hot (1959)',
#  314: 'Face/Off (1997)',
#  315: 'Sleepy Hollow (1999)',
#  316: 'The Imitation Game (2014)',
#  317: 'Piano, The (1993)',
#  318: 'Pianist, The (2002)',
#  319: 'Deadpool (2016)',
#  320: 'Fantasia (1940)',
#  321: 'Natural Born Killers (1994)',
#  322: 'School of Rock (2003)',
#  323: 'Training Day (2001)',
#  324: 'Gran Torino (2008)',
#  325: 'Goldfinger (1964)',
#  326: 'Harry Potter and the Deathly Hallows: Part 2 (2011)',
#  327: 'Boondock Saints, The (2000)',
#  328: 'Grand Budapest Hotel, The (2014)',
#  329: 'Adaptation (2002)',
#  330: 'Abyss, The (1989)',
#  331: 'Skyfall (2012)',
#  332: 'I, Robot (2004)',
#  333: 'Mystic River (2003)',
#  334: 'Maltese Falcon, The (1941)',
#  335: 'Blow (2001)',
#  336: 'Mulholland Drive (2001)',
#  337: 'Pi (1998)',
#  338: 'Others, The (2001)',
#  339: 'Planet of the Apes (1968)',
#  340: 'Lawrence of Arabia (1962)',
#  341: 'Edge of Tomorrow (2014)',
#  342: 'Knocked Up (2007)',
#  343: 'Superman (1978)',
#  344: 'Exorcist, The (1973)',
#  345: 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)',
#  346: 'Wedding Crashers (2005)',
#  347: 'Equilibrium (2002)',
#  348: 'Spaceballs (1987)',
#  349: 'Waterworld (1995)',
#  350: 'Magnolia (1999)',
#  351: 'Black Hawk Down (2001)',
#  352: 'Enemy of the State (1998)',
#  353: 'Election (1999)',
#  354: 'Pleasantville (1998)',
#  355: 'Die Hard 2 (1990)',
#  356: 'Moulin Rouge (2001)',
#  357: 'Mars Attacks! (1996)',
#  358: 'Home Alone (1990)',
#  359: "Singin' in the Rain (1952)",
#  360: 'Dark City (1998)',
#  361: 'Unforgiven (1992)',
#  362: 'Caddyshack (1980)',
#  363: 'X-Men: First Class (2011)',
#  364: 'Net, The (1995)',
#  365: "Pirates of the Caribbean: At World's End (2007)",
#  366: 'Bridge on the River Kwai, The (1957)',
#  367: 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)',
#  368: 'Blue Velvet (1986)',
#  369: 'Great Escape, The (1963)',
#  370: 'Desperado (1995)',
#  371: 'Little Mermaid, The (1989)',
#  372: 'Kung Fu Panda (2008)',
#  373: 'Wallace & Gromit: A Close Shave (1995)',
#  374: 'Chicago (2002)',
#  375: 'RoboCop (1987)',
#  376: 'Jungle Book, The (1967)',
#  377: 'In Bruges (2008)',
#  378: 'The Hunger Games (2012)',
#  379: 'Harry Potter and the Deathly Hallows: Part 1 (2010)',
#  380: 'Watchmen (2009)',
#  381: "Wayne's World (1992)",
#  382: 'Glory (1989)',
#  383: 'Legends of the Fall (1994)',
#  384: 'The Butterfly Effect (2004)',
#  385: 'Stranger than Fiction (2006)',
#  386: 'Best in Show (2000)',
#  387: 'About a Boy (2002)',
#  388: 'Bruce Almighty (2003)',
#  389: 'From Dusk Till Dawn (1996)',
#  390: 'Jackie Brown (1997)',
#  391: 'Donnie Brasco (1997)',
#  392: 'Grosse Pointe Blank (1997)',
#  393: 'M*A*S*H (a.k.a. MASH) (1970)',
#  394: 'Super Size Me (2004)',
#  395: 'Garden State (2004)',
#  396: 'Misery (1990)',
#  397: 'Into the Wild (2007)',
#  398: 'Thing, The (1982)',
#  399: 'Star Wars: Episode VII - The Force Awakens (2015)',
#  400: 'Chasing Amy (1997)',
#  401: 'Simpsons Movie, The (2007)',
#  402: 'My Big Fat Greek Wedding (2002)',
#  403: 'Goonies, The (1985)',
#  404: 'Santa Clause, The (1994)',
#  405: 'Gangs of New York (2002)',
#  406: 'Crow, The (1994)',
#  407: 'Fear and Loathing in Las Vegas (1998)',
#  408: 'Notting Hill (1999)',
#  409: 'Armageddon (1998)',
#  410: 'Boot, Das (Boat, The) (1981)',
#  411: 'Pinocchio (1940)',
#  412: 'Sling Blade (1996)',
#  413: 'Rushmore (1998)',
#  414: "Howl's Moving Castle (Hauru no ugoku shiro) (2004)",
#  415: 'Blade (1998)',
#  416: 'Scream (1996)',
#  417: 'Raging Bull (1980)',
#  418: 'Pursuit of Happyness, The (2006)',
#  419: 'Inside Out (2015)',
#  420: 'Big Hero 6 (2014)',
#  421: 'Signs (2002)',
#  422: 'Boogie Nights (1997)',
#  423: 'Mad Max: Fury Road (2015)',
#  424: 'Black Swan (2010)',
#  425: '10 Things I Hate About You (1999)',
#  426: '50 First Dates (2004)',
#  427: 'Tommy Boy (1995)',
#  428: "Monty Python's The Meaning of Life (1983)",
#  429: 'Illusionist, The (2006)',
#  430: 'Highlander (1986)',
#  431: 'Collateral (2004)',
#  432: 'Walk the Line (2005)',
#  433: 'Legally Blonde (2001)',
#  434: 'City of Lost Children, The (Cité des enfants perdus, La) (1995)',
#  435: 'The Machinist (2004)',
#  436: 'Dog Day Afternoon (1975)',
#  437: 'Old Boy (2003)',
#  438: 'Iron Man 2 (2010)',
#  439: 'Iron Giant, The (1999)',
#  440: 'Kick-Ass (2010)',
#  441: 'My Neighbor Totoro (Tonari no Totoro) (1988)',
#  442: 'Mr. & Mrs. Smith (2005)',
#  443: 'Three Kings (1999)',
#  444: 'Thomas Crown Affair, The (1999)',
#  445: 'Kingsman: The Secret Service (2015)',
#  446: 'Field of Dreams (1989)',
#  447: 'Billy Elliot (2000)',
#  448: 'Grease (1978)',
#  449: 'Kiss Kiss Bang Bang (2005)',
#  450: 'Dazed and Confused (1993)',
#  451: 'American Graffiti (1973)',
#  452: 'Whiplash (2014)',
#  453: 'Lives of Others, The (Das leben der Anderen) (2006)',
#  454: '(500) Days of Summer (2009)',
#  455: 'Zoolander (2001)',
#  456: 'American Gangster (2007)',
#  457: 'Demolition Man (1993)',
#  458: 'Wedding Singer, The (1998)',
#  459: 'Remember the Titans (2000)',
#  460: 'Batman Forever (1995)',
#  461: 'Road to Perdition (2002)',
#  462: 'X-Men: The Last Stand (2006)',
#  463: 'Fistful of Dollars, A (Per un pugno di dollari) (1964)',
#  464: 'Gone in 60 Seconds (2000)',
#  465: 'Lady and the Tramp (1955)',
#  466: 'Corpse Bride (2005)',
#  467: 'Labyrinth (1986)',
#  468: 'Sixteen Candles (1984)',
#  469: 'Sherlock Holmes: A Game of Shadows (2011)',
#  470: 'Birds, The (1963)',
#  471: 'Lucky Number Slevin (2006)',
#  472: 'A.I. Artificial Intelligence (2001)',
#  473: 'Femme Nikita, La (Nikita) (1990)',
#  474: 'Deer Hunter, The (1978)',
#  475: 'Hobbit: An Unexpected Journey, The (2012)',
#  476: "Bill & Ted's Excellent Adventure (1989)",
#  477: 'Mulan (1998)',
#  478: 'Little Women (1994)',
#  479: 'Thank You for Smoking (2006)',
#  480: 'Scott Pilgrim vs. the World (2010)',
#  481: 'Rocky Horror Picture Show, The (1975)',
#  482: 'Inside Man (2006)',
#  483: 'Hurt Locker, The (2008)',
#  484: 'Mean Girls (2004)',
#  485: 'Romancing the Stone (1984)',
#  486: 'Much Ado About Nothing (1993)',
#  487: 'My Fair Lady (1964)',
#  488: "Carlito's Way (1993)",
#  489: 'Hero (Ying xiong) (2002)',
#  490: 'Akira (1988)',
#  491: 'Good Morning, Vietnam (1987)',
#  492: 'For a Few Dollars More (Per qualche dollaro in più) (1965)',
#  493: 'Eyes Wide Shut (1999)',
#  494: 'Talented Mr. Ripley, The (1999)',
#  495: 'Intouchables (2011)',
#  496: 'Mask of Zorro, The (1998)',
#  497: 'Road Warrior, The (Mad Max 2) (1981)',
#  498: 'French Connection, The (1971)',
#  499: 'Robin Hood: Men in Tights (1993)',
#  500: 'Forgetting Sarah Marshall (2008)',
#  501: 'Hook (1991)',
#  502: 'Bonnie and Clyde (1967)',
#  503: "Hitchhiker's Guide to the Galaxy, The (2005)",
#  504: 'Truth About Cats & Dogs, The (1996)',
#  505: 'Chocolat (2000)',
#  506: 'Despicable Me (2010)',
#  507: 'Searching for Bobby Fischer (1993)',
#  508: 'Time Bandits (1981)',
#  509: 'English Patient, The (1996)',
#  510: 'Poltergeist (1982)',
#  511: 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)',
#  512: 'Ace Ventura: When Nature Calls (1995)',
#  513: "Rosemary's Baby (1968)",
#  514: 'Postman, The (Postino, Il) (1994)',
#  515: 'Liar Liar (1997)',
#  516: 'Pocahontas (1995)',
#  517: 'Girl with the Dragon Tattoo, The (2011)',
#  518: 'Elf (2003)',
#  519: 'Go (1999)',
#  520: 'War of the Worlds (2005)',
#  521: 'Dirty Dozen, The (1967)',
#  522: 'Manhattan (1979)',
#  523: 'Beverly Hills Cop (1984)',
#  524: 'Gone Girl (2014)',
#  525: 'Evil Dead II (Dead by Dawn) (1987)',
#  526: 'Terminal, The (2004)',
#  527: "Breakfast at Tiffany's (1961)",
#  528: 'Curious Case of Benjamin Button, The (2008)',
#  529: 'Sideways (2004)',
#  530: 'Pitch Black (2000)',
#  531: 'Troy (2004)',
#  532: 'Broken Arrow (1996)',
#  533: "The Devil's Advocate (1997)",
#  534: 'Rounders (1998)',
#  535: 'Charlie and the Chocolate Factory (2005)',
#  536: 'Taken (2008)',
#  537: 'Dodgeball: A True Underdog Story (2004)',
#  538: 'NeverEnding Story, The (1984)',
#  539: 'Master and Commander: The Far Side of the World (2003)',
#  540: 'Miss Congeniality (2000)',
#  541: 'Fast Times at Ridgemont High (1982)',
#  542: 'Blair Witch Project, The (1999)',
#  543: 'Ben-Hur (1959)',
#  544: 'Crazy, Stupid, Love. (2011)',
#  545: 'Adventures of Priscilla, Queen of the Desert, The (1994)',
#  546: 'African Queen, The (1951)',
#  547: 'Vanilla Sky (2001)',
#  548: 'Fahrenheit 9/11 (2004)',
#  549: 'Say Anything... (1989)',
#  550: 'Zodiac (2007)',
#  551: 'Trading Places (1983)',
#  552: 'What Women Want (2000)',
#  553: 'Sneakers (1992)',
#  554: 'Lord of War (2005)',
#  555: 'Manchurian Candidate, The (1962)',
#  556: 'Producers, The (1968)',
#  557: 'Heathers (1989)',
#  558: 'Moon (2009)',
#  559: 'Matchstick Men (2003)',
#  560: 'League of Their Own, A (1992)',
#  561: 'My Cousin Vinny (1992)',
#  562: 'Wrestler, The (2008)',
#  563: 'Last of the Mohicans, The (1992)',
#  564: "Emperor's New Groove, The (2000)",
#  565: 'Whole Nine Yards, The (2000)',
#  566: 'Client, The (1994)',
#  567: "You've Got Mail (1998)",
#  568: 'Gone with the Wind (1939)',
#  569: 'Notebook, The (2004)',
#  570: 'Patton (1970)',
#  571: 'Ring, The (2002)',
#  572: 'The Count of Monte Cristo (2002)',
#  573: 'Air Force One (1997)',
#  574: 'Star Trek IV: The Voyage Home (1986)',
#  575: 'Disclosure (1994)',
#  576: 'Swingers (1996)',
#  577: 'Crocodile Dundee (1986)',
#  578: 'Addams Family Values (1993)',
#  579: 'Player, The (1992)',
#  580: "Boys Don't Cry (1999)",
#  581: 'Philadelphia Story, The (1940)',
#  582: 'Austin Powers in Goldmember (2002)',
#  583: "All the President's Men (1976)",
#  584: 'The Lego Movie (2014)',
#  585: 'Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)',
#  586: 'Coraline (2009)',
#  587: 'Cliffhanger (1993)',
#  588: 'Drive (2011)',
#  589: 'Battle Royale (Batoru rowaiaru) (2000)',
#  590: 'Nutty Professor, The (1996)',
#  591: 'Dirty Dancing (1987)',
#  592: 'Don Juan DeMarco (1995)',
#  593: 'Ghost in the Shell (Kôkaku kidôtai) (1995)',
#  594: 'Witness (1985)',
#  595: 'Da Vinci Code, The (2006)',
#  596: 'Finding Neverland (2004)',
#  597: 'Ronin (1998)',
#  598: 'Splash (1984)',
#  599: 'Enemy at the Gates (2001)',
#  600: 'Rumble in the Bronx (Hont faan kui) (1995)',
#  601: 'Devil Wears Prada, The (2006)',
#  602: '101 Dalmatians (One Hundred and One Dalmatians) (1961)',
#  603: 'Man on Fire (2004)',
#  604: 'Source Code (2011)',
#  605: 'Hunchback of Notre Dame, The (1996)',
#  606: 'Dune (1984)',
#  607: 'Time to Kill, A (1996)',
#  608: 'Big Daddy (1999)',
#  609: 'Mystery Science Theater 3000: The Movie (1996)',
#  610: 'Con Air (1997)',
#  611: 'King Kong (2005)',
#  612: 'Old School (2003)',
#  613: 'Aviator, The (2004)',
#  614: 'Bad Boys (1995)',
#  615: 'Rob Roy (1995)',
#  616: 'Arsenic and Old Lace (1944)',
#  617: 'Zootopia (2016)',
#  618: 'Insider, The (1999)',
#  619: 'Karate Kid, The (1984)',
#  620: 'Aristocats, The (1970)',
#  621: 'Billy Madison (1995)',
#  622: '8 Mile (2002)',
#  623: 'Stardust (2007)',
#  624: 'Blind Side, The  (2009)',
#  625: 'Star Trek VI: The Undiscovered Country (1991)',
#  626: 'Mad Max (1979)',
#  627: 'Peter Pan (1953)',
#  628: 'Limitless (2011)',
#  629: "Monty Python's And Now for Something Completely Different (1971)",
#  630: 'Roger & Me (1989)',
#  631: 'Up in the Air (2009)',
#  632: 'Hoop Dreams (1994)',
#  633: 'Grand Day Out with Wallace and Gromit, A (1989)',
#  634: 'X-Files: Fight the Future, The (1998)',
#  635: 'Hellboy (2004)',
#  636: 'Killing Fields, The (1984)',
#  637: 'Lilo & Stitch (2002)',
#  638: 'National Treasure (2004)',
#  639: 'Naked Gun: From the Files of Police Squad!, The (1988)',
#  640: "My Best Friend's Wedding (1997)",
#  641: 'Three Musketeers, The (1993)',
#  642: 'Mummy Returns, The (2001)',
#  643: 'Cars (2006)',
#  644: 'There Will Be Blood (2007)',
#  645: 'Thelma & Louise (1991)',
#  646: 'James and the Giant Peach (1996)',
#  647: 'Payback (1999)',
#  648: 'Argo (2012)',
#  649: 'Do the Right Thing (1989)',
#  650: 'Deliverance (1972)',
#  651: 'Captain America: The Winter Soldier (2014)',
#  652: 'Eraser (1996)',
#  653: "William Shakespeare's Romeo + Juliet (1996)",
#  654: 'Mallrats (1995)',
#  655: 'Easy A (2010)',
#  656: 'Guardians of the Galaxy 2 (2017)',
#  657: 'Harold and Maude (1971)',
#  658: 'Bend It Like Beckham (2002)',
#  659: 'Life of Pi (2012)',
#  660: 'Yes Man (2008)',
#  661: 'Quantum of Solace (2008)',
#  662: 'X-Men: Days of Future Past (2014)',
#  663: 'October Sky (1999)',
#  664: 'Muppet Movie, The (1979)',
#  665: 'Dial M for Murder (1954)',
#  666: 'Thor (2011)',
#  667: 'I.Q. (1994)',
#  668: 'Logan (2017)',
#  669: 'Batman Returns (1992)',
#  670: 'First Knight (1995)',
#  671: 'Mission: Impossible II (2000)',
#  672: 'John Wick (2014)',
#  673: 'Stripes (1981)',
#  674: 'Fisher King, The (1991)',
#  675: 'Silver Linings Playbook (2012)',
#  676: 'American Pie 2 (2001)',
#  677: "Charlie's Angels (2000)",
#  678: 'Grumpier Old Men (1995)',
#  679: 'Harold and Kumar Go to White Castle (2004)',
#  680: 'Risky Business (1983)',
#  681: 'Tron (1982)',
#  682: 'Gremlins (1984)',
#  683: 'In the Name of the Father (1993)',
#  684: 'Out of Sight (1998)',
#  685: 'Dark Crystal, The (1982)',
#  686: 'Sabrina (1954)',
#  687: 'Sabrina (1995)',
#  688: 'Man on the Moon (1999)',
#  689: 'Captain America: The First Avenger (2011)',
#  690: 'Madagascar (2005)',
#  691: "Ocean's Twelve (2004)",
#  692: 'All About Eve (1950)',
#  693: 'Big Trouble in Little China (1986)',
#  694: 'Shanghai Noon (2000)',
#  695: 'Fly, The (1986)',
#  696: 'So I Married an Axe Murderer (1993)',
#  697: 'Hudsucker Proxy, The (1994)',
#  698: 'Ex Machina (2015)',
#  699: 'Moneyball (2011)',
#  700: 'Rush Hour (1998)',
#  701: 'Cocoon (1985)',
#  702: 'Sweeney Todd: The Demon Barber of Fleet Street (2007)',
#  703: 'From Russia with Love (1963)',
#  704: 'Dr. No (1962)',
#  705: 'Apartment, The (1960)',
#  706: 'Crying Game, The (1992)',
#  707: 'Babel (2006)',
#  708: 'Wallace & Gromit: The Best of Aardman Animation (1996)',
#  709: 'Naked Gun 33 1/3: The Final Insult (1994)',
#  710: 'The Revenant (2015)',
#  711: 'French Kiss (1995)',
#  712: 'Godfather: Part III, The (1990)',
#  713: 'Like Water for Chocolate (Como agua para chocolate) (1992)',
#  714: 'Bull Durham (1988)',
#  715: 'Moonrise Kingdom (2012)',
#  716: 'Dragonheart (1996)',
#  717: 'Burn After Reading (2008)',
#  718: 'Transformers (2007)',
#  719: 'Alice in Wonderland (1951)',
#  720: 'Me, Myself & Irene (2000)',
#  721: "Knight's Tale, A (2001)",
#  722: 'Brokeback Mountain (2005)',
#  723: 'Ghost World (2001)',
#  724: '3:10 to Yuma (2007)',
#  725: 'Lethal Weapon 2 (1989)',
#  726: 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)',
#  727: 'Little Shop of Horrors (1986)',
#  728: 'Kingpin (1996)',
#  729: 'Frozen (2013)',
#  730: 'Hitch (2005)',
#  731: 'Little Big Man (1970)',
#  732: 'Life Aquatic with Steve Zissou, The (2004)',
#  733: 'Looper (2012)',
#  734: 'Hercules (1997)',
#  735: 'Gandhi (1982)',
#  736: 'Phenomenon (1996)',
#  737: 'Cruel Intentions (1999)',
#  738: 'Town, The (2010)',
#  739: 'Star Trek III: The Search for Spock (1984)',
#  740: 'Tropic Thunder (2008)',
#  741: 'True Grit (2010)',
#  742: 'Alien³ (a.k.a. Alien 3) (1992)',
#  743: 'Emma (1996)',
#  744: 'Team America: World Police (2004)',
#  745: 'On the Waterfront (1954)',
#  746: 'To Catch a Thief (1955)',
#  747: 'Dangerous Liaisons (1988)',
#  748: 'Primal Fear (1996)',
#  749: 'Punch-Drunk Love (2002)',
#  750: 'Motorcycle Diaries, The (Diarios de motocicleta) (2004)',
#  751: 'Easy Rider (1969)',
#  752: 'Shine (1996)',
#  753: 'Perfect Storm, The (2000)',
#  754: 'Capote (2005)',
#  755: 'Pineapple Express (2008)',
#  756: 'Rogue One: A Star Wars Story (2016)',
#  757: 'Madness of King George, The (1994)',
#  758: 'Willow (1988)',
#  759: 'Ant-Man (2015)',
#  760: 'Arrival (2016)',
#  761: 'Secretary (2002)',
#  762: 'Cinderella (1950)',
#  763: 'Tangled (2010)',
#  764: 'Third Man, The (1949)',
#  765: 'Frequency (2000)',
#  766: 'Terminator 3: Rise of the Machines (2003)',
#  767: 'The Hunger Games: Mockingjay - Part 1 (2014)',
#  768: 'The Hunger Games: Catching Fire (2013)',
#  769: 'Spider-Man 3 (2007)',
#  770: 'Pride & Prejudice (2005)',
#  771: 'Strangers on a Train (1951)',
#  772: 'JFK (1991)',
#  773: 'Bambi (1942)',
#  774: 'Finding Forrester (2000)',
#  775: "Dr. Horrible's Sing-Along Blog (2008)",
#  776: 'Sleepers (1996)',
#  777: 'Sleeper (1973)',
#  778: 'Planes, Trains & Automobiles (1987)',
#  779: 'Day After Tomorrow, The (2004)',
#  780: 'Doors, The (1991)',
#  781: 'Roman Holiday (1953)',
#  782: 'Lost World: Jurassic Park, The (1997)',
#  783: 'Napoleon Dynamite (2004)',
#  784: 'Island, The (2005)',
#  785: 'Waking Ned Devine (a.k.a. Waking Ned) (1998)',
#  786: 'Antz (1998)',
#  787: 'Before Sunrise (1995)',
#  788: 'Tootsie (1982)',
#  789: 'Gravity (2013)',
#  790: 'World Is Not Enough, The (1999)',
#  791: "Christmas Vacation (National Lampoon's Christmas Vacation) (1989)",
#  792: 'Mission: Impossible III (2006)',
#  793: 'Mystery Men (1999)',
#  794: 'Basic Instinct (1992)',
#  795: 'Tin Cup (1996)',
#  796: 'Carrie (1976)',
#  797: 'Road Trip (2000)',
#  798: 'Underworld (2003)',
#  799: 'Three Colors: Blue (Trois couleurs: Bleu) (1993)',
#  800: 'Escape from New York (1981)',
#  801: 'Iron Man 3 (2013)',
#  802: 'K-PAX (2001)',
#  803: '21 Jump Street (2012)',
#  804: 'Wallace & Gromit in The Curse of the Were-Rabbit (2005)',
#  805: 'Shooter (2007)',
#  806: 'Girl with the Dragon Tattoo, The (Män som hatar kvinnor) (2009)',
#  807: 'West Side Story (1961)',
#  808: 'Dumbo (1941)',
#  809: 'Hot Shots! Part Deux (1993)',
#  810: 'House of Flying Daggers (Shi mian mai fu) (2004)',
#  811: 'Rise of the Planet of the Apes (2011)',
#  812: 'Jay and Silent Bob Strike Back (2001)',
#  813: 'Pearl Harbor (2001)',
#  814: 'Jungle Book, The (1994)',
#  815: 'People vs. Larry Flynt, The (1996)',
#  816: 'Saw (2004)',
#  817: 'Cider House Rules, The (1999)',
#  818: 'U-571 (2000)',
#  819: 'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)',
#  820: 'Notorious (1946)',
#  821: 'Thin Red Line, The (1998)',
#  822: 'Brave (2012)',
#  823: 'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)',
#  824: 'Network (1976)',
#  825: 'Modern Times (1936)',
#  826: 'Bound (1996)',
#  827: 'Final Fantasy: The Spirits Within (2001)',
#  828: 'Star Trek Into Darkness (2013)',
#  829: 'Transporter, The (2002)',
#  830: "Ocean's Thirteen (2007)",
#  831: 'Heavy Metal (1981)',
#  832: 'Gosford Park (2001)',
#  833: 'Executive Decision (1996)',
#  834: 'Big Short, The (2015)',
#  835: 'Incredible Hulk, The (2008)',
#  836: 'Cell, The (2000)',
#  837: 'Robin Hood (1973)',
#  838: 'Return of the Pink Panther, The (1975)',
#  839: 'Rudy (1993)',
#  840: 'Lost Boys, The (1987)',
#  841: 'Scary Movie (2000)',
#  842: 'Scent of a Woman (1992)',
#  843: 'eXistenZ (1999)',
#  844: 'Wreck-It Ralph (2012)',
#  845: 'Gods Must Be Crazy, The (1980)',
#  846: '25th Hour (2002)',
#  847: 'Virgin Suicides, The (1999)',
#  848: 'Tomorrow Never Dies (1997)',
#  849: 'Three Colors: White (Trzy kolory: Bialy) (1994)',
#  850: 'Grifters, The (1990)',
#  851: 'Constantine (2005)',
#  852: 'Fried Green Tomatoes (1991)',
#  853: 'Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku no Tobira) (2001)',
#  854: 'Fighter, The (2010)',
#  855: 'Streetcar Named Desire, A (1951)',
#  856: 'Cube (1997)',
#  857: 'Help, The (2011)',
#  858: 'Her (2013)',
#  859: 'Honey, I Shrunk the Kids (1989)',
#  860: 'Hoosiers (a.k.a. Best Shot) (1986)',
#  861: 'Day the Earth Stood Still, The (1951)',
#  862: "Amores Perros (Love's a Bitch) (2000)",
#  863: 'Analyze This (1999)',
#  864: 'Red Dragon (2002)',
#  865: 'First Blood (Rambo: First Blood) (1982)',
#  866: 'Driving Miss Daisy (1989)',
#  867: 'Doctor Zhivago (1965)',
#  868: 'Entrapment (1999)',
#  869: 'Cape Fear (1991)',
#  870: 'Live Free or Die Hard (2007)',
#  871: "Miller's Crossing (1990)",
#  872: 'Lara Croft: Tomb Raider (2001)',
#  873: "National Lampoon's Vacation (1983)",
#  874: 'Nell (1994)',
#  875: 'Night of the Living Dead (1968)',
#  876: 'Panic Room (2002)',
#  877: 'Patriot Games (1992)',
#  878: 'Avengers: Age of Ultron (2015)',
#  879: "Jacob's Ladder (1990)",
#  880: 'Last Emperor, The (1987)',
#  881: 'Casper (1995)',
#  882: 'Deep Impact (1998)',
#  883: 'Waiting for Guffman (1996)',
#  884: 'Bullets Over Broadway (1994)',
#  885: 'Superman II (1980)',
#  886: 'Captain Phillips (2013)',
#  887: 'And Your Mother Too (Y tu mamá también) (2001)',
#  888: 'Dancer in the Dark (2000)',
#  889: 'Delicatessen (1991)',
#  890: 'Dangerous Minds (1995)',
#  891: 'Bad Santa (2003)',
#  892: '28 Weeks Later (2007)',
#  893: 'Eastern Promises (2007)',
#  894: 'Addams Family, The (1991)',
#  895: 'Patch Adams (1998)',
#  896: "Muriel's Wedding (1994)",
#  897: 'Amazing Spider-Man, The (2012)',
#  898: 'Big Chill, The (1983)',
#  899: 'Hobbit: The Desolation of Smaug, The (2013)',
#  900: 'Downfall (Untergang, Der) (2004)',
#  901: 'Fatal Attraction (1987)',
#  902: 'All About My Mother (Todo sobre mi madre) (1999)',
#  903: 'Meet the Fockers (2004)',
#  904: 'Ransom (1996)',
#  905: 'Cinderella Man (2005)',
#  906: 'Step Brothers (2008)',
#  907: 'Duck Soup (1933)',
#  908: 'Right Stuff, The (1983)',
#  909: 'Dogville (2003)',
#  910: 'Cabin in the Woods, The (2012)',
#  911: 'Bottle Rocket (1996)',
#  912: 'Spotlight (2015)',
#  913: 'Matilda (1996)',
#  914: 'Last King of Scotland, The (2006)',
#  915: "Dracula (Bram Stoker's Dracula) (1992)",
#  916: 'Girl, Interrupted (1999)',
#  917: 'Little Princess, A (1995)',
#  918: 'Phone Booth (2002)',
#  919: 'Swordfish (2001)',
#  920: 'Fast and the Furious, The (2001)',
#  921: 'Cable Guy, The (1996)',
#  922: 'Professional, The (Le professionnel) (1981)',
#  923: 'Negotiator, The (1998)',
#  924: 'Natural, The (1984)',
#  925: 'Red Violin, The (Violon rouge, Le) (1998)',
#  926: 'Crumb (1994)',
#  927: 'Nightcrawler (2014)',
#  928: 'Star Trek: The Motion Picture (1979)',
#  929: 'Crimes and Misdemeanors (1989)',
#  930: 'Sword in the Stone, The (1963)',
#  931: 'Layer Cake (2004)',
#  932: 'Thor: Ragnarok (2017)',
#  933: 'Long Kiss Goodnight, The (1996)',
#  934: 'Zack and Miri Make a Porno (2008)',
#  935: 'Lone Star (1996)',
#  936: 'Evil Dead, The (1981)',
#  937: 'Escape from L.A. (1996)',
#  938: 'Rashomon (Rashômon) (1950)',
#  939: 'Wonder Boys (2000)',
#  940: 'Ghostbusters II (1989)',
#  941: 'What About Bob? (1991)',
#  942: "We're the Millers (2013)",
#  943: 'Better Off Dead... (1985)',
#  944: 'Bridesmaids (2011)',
#  945: 'Beach, The (2000)',
#  946: 'Good Night, and Good Luck. (2005)',
#  947: 'Good bye, Lenin! (2003)',
#  948: 'Metropolis (1927)',
#  949: 'Elizabeth (1998)',
#  950: 'Midnight Cowboy (1969)',
#  951: 'Triplets of Belleville, The (Les triplettes de Belleville) (2003)',
#  952: 'Midnight in Paris (2011)',
#  953: 'Moonstruck (1987)',
#  954: 'Star Trek: Insurrection (1998)',
#  955: 'Munich (2005)',
#  956: 'Grindhouse (2007)',
#  957: 'Conspiracy Theory (1997)',
#  958: 'Congo (1995)',
#  959: 'Ray (2004)',
#  960: 'History of Violence, A (2005)',
#  961: 'Identity (2003)',
#  962: 'Kids (1995)',
#  963: 'Double Indemnity (1944)',
#  964: 'Secret Life of Walter Mitty, The (2013)',
#  965: 'Role Models (2008)',
#  966: 'Rush Hour 2 (2001)',
#  967: 'Pink Floyd: The Wall (1982)',
#  968: 'Dirty Harry (1971)',
#  969: 'Simple Plan, A (1998)',
#  970: 'Scanner Darkly, A (2006)',
#  971: 'Pitch Perfect (2012)',
#  972: 'Awakenings (1990)',
#  973: 'Outlaw Josey Wales, The (1976)',
#  974: 'Planet Terror (2007)',
#  975: 'Death Proof (2007)',
#  976: 'Sliding Doors (1998)',
#  977: 'Horrible Bosses (2011)',
#  978: 'Boiler Room (2000)',
#  979: 'High Noon (1952)',
#  980: "Once Upon a Time in the West (C'era una volta il West) (1968)",
#  981: 'Hustler, The (1961)',
#  982: 'Henry V (1989)',
#  983: 'Pay It Forward (2000)',
#  984: 'Hellboy II: The Golden Army (2008)',
#  985: 'Alien: Resurrection (1997)',
#  986: 'River Wild, The (1994)',
#  987: 'River Runs Through It, A (1992)',
#  988: 'Private Parts (1997)',
#  989: 'Seventh Seal, The (Sjunde inseglet, Det) (1957)',
#  990: 'Megamind (2010)',
#  991: 'Anger Management (2003)',
#  992: 'Now You See Me (2013)',
#  993: 'Wall Street (1987)',
#  994: 'I Heart Huckabees (2004)',
#  995: 'Johnny Mnemonic (1995)',
#  996: 'Wag the Dog (1997)',
#  997: 'Perks of Being a Wallflower, The (2012)',
#  998: 'Untitled Spider-Man Reboot (2017)',
#  999: 'Despicable Me 2 (2013)',
#  ...}

# %%
sequences_int=[]
for seq in sequences:
    movielist=[]
    for movie in seq:
        movielist.append(voc_index[movie])
    sequences_int.append(movielist)

# %%
sequences_int[:5]
# Out:
# [[2970,
#   16,
#   773,
#   144,
#   1561,
#   30,
#   797,
#   1853,
#   911,
#   450,
#   11,
#   6189,
#   106,
#   258,
#   576,
#   1,
#   392,
#   180,
#   413,
#   142,
#   381,
#   91,
#   1531,
#   1037,
#   232,
#   427,
#   696,
#   1070,
#   621,
#   213,
#   941,
#   458,
#   678,
#   200,
#   109,
#   126,
#   41,
#   3448,
#   907,
#   1334,
#   184,
#   238,
#   5,
#   83,
#   86,
#   198,
#   1005,
#   147,
#   467,
#   403,
#   538,
#   758,
#   146,
#   681,
#   1890,
#   1413,
#   859,
#   501,
#   2080,
#   2636,
#   4533,
#   10,
#   9,
#   40,
#   153,
#   63,
#   35,
#   521,
#   1393,
#   19,
#   3,
#   704,
#   23,
#   175,
#   93,
#   36,
#   497,
#   8,
#   1947,
#   241,
#   325,
#   703,
#   221,
#   112,
#   821,
#   339,
#   1171,
#   97,
#   1060,
#   302,
#   1316,
#   430,
#   314,
#   194,
#   700,
#   485,
#   1607,
#   15,
#   1051,
#   3559,
#   343,
#   111,
#   1245,
#   923,
#   693,
#   1031,
#   137,
#   165,
#   751,
#   330,
#   118,
#   43,
#   161,
#   1269,
#   814,
#   3166,
#   577,
#   610,
#   4427,
#   885,
#   641,
#   1222,
#   1010,
#   1868,
#   17,
#   320,
#   439,
#   6581,
#   930,
#   719,
#   2163,
#   1197,
#   1140,
#   837,
#   411,
#   646,
#   376,
#   2183,
#   1311,
#   1582,
#   808,
#   2754,
#   2090,
#   2280,
#   2297,
#   12,
#   24,
#   48,
#   42,
#   101,
#   295,
#   519,
#   5839,
#   375,
#   2459,
#   1111,
#   1480,
#   1457,
#   1052,
#   79,
#   46,
#   6,
#   1433,
#   2104,
#   3178,
#   197,
#   1620,
#   1522,
#   87,
#   794,
#   772,
#   199,
#   1587,
#   51,
#   2047,
#   3176,
#   370,
#   176,
#   25,
#   53,
#   70,
#   626,
#   348,
#   4,
#   21,
#   352,
#   62,
#   7,
#   393,
#   225,
#   982,
#   615,
#   491,
#   967,
#   1742,
#   2895,
#   257,
#   1317,
#   276,
#   2705],
#  [38,
#   4475,
#   698,
#   188,
#   452,
#   30,
#   151,
#   196,
#   52,
#   431,
#   304,
#   906,
#   1065,
#   427,
#   68,
#   31,
#   103,
#   1676,
#   1259,
#   1796,
#   45,
#   423,
#   738],
#  [430,
#   497,
#   937,
#   398,
#   4958,
#   4185,
#   4753,
#   4017,
#   2873,
#   3820,
#   3795,
#   6640,
#   5236,
#   1051,
#   6347,
#   6198,
#   7066],
#  [527,
#   1745,
#   926,
#   2005,
#   310,
#   979,
#   1387,
#   1784,
#   1513,
#   467,
#   153,
#   368,
#   787,
#   935,
#   2633,
#   2206,
#   1204,
#   930,
#   5,
#   23,
#   502,
#   83,
#   137,
#   376,
#   320,
#   359,
#   204,
#   807,
#   34,
#   487,
#   42,
#   2028,
#   883,
#   142,
#   169,
#   116,
#   1080,
#   1357,
#   91,
#   1817,
#   1062,
#   391,
#   568,
#   2525,
#   777,
#   243,
#   85,
#   313,
#   366,
#   771,
#   228,
#   1529,
#   683,
#   545,
#   1625,
#   2042,
#   973,
#   713,
#   896,
#   1094,
#   820,
#   115,
#   10,
#   35,
#   36,
#   350,
#   11,
#   850,
#   150,
#   772,
#   143,
#   665,
#   1130,
#   494,
#   2196,
#   198,
#   155,
#   4,
#   27,
#   24,
#   3348,
#   902,
#   1169,
#   785,
#   1209,
#   51,
#   1310,
#   353,
#   1865,
#   1790,
#   1661,
#   291,
#   884,
#   392,
#   560,
#   581,
#   106,
#   335,
#   179,
#   5888,
#   361,
#   90,
#   1249,
#   447,
#   7002,
#   2180,
#   269,
#   140,
#   939,
#   41,
#   126,
#   845,
#   99,
#   2185,
#   1177,
#   2602,
#   1158,
#   3893,
#   504,
#   485,
#   348,
#   1244,
#   2994,
#   2046,
#   2969,
#   3835,
#   108,
#   266],
#  [43,
#   2,
#   23,
#   34,
#   80,
#   8,
#   12,
#   100,
#   7,
#   17,
#   147,
#   244,
#   514,
#   478,
#   268,
#   1415,
#   411,
#   1310,
#   226,
#   683,
#   1356,
#   1044,
#   285]]

# %%
vocab_size=len(voc_index)

# %%
vocab_size
# Out:
# 7359

# %%
def generate_training_data(sequences,vocab_size,window_size=5, num_ns=5,seed=44):
    targets, contexts, labels = [], [], []
    # 采样时对zipf分布数据加权,对于高频的以更小的概率被采样到。
    #sampling_table = tf.keras.preprocessing.sequence.make_sampling_table(vocab_size)
    for seq in tqdm.tqdm(sequences):
        # 对每一个会话生成正样本
        positive_skip_grams,_=tf.keras.preprocessing.sequence.skipgrams(
                                seq,
                                vocabulary_size=vocab_size,
                                #sampling_table=sampling_table #不做限制时表示采样窗口内的所有正样本，否则按照sampling_table中的概率进行采样
                                window_size=window_size,
                                negative_samples=0 # 不进行负采样  
                            )
        # 按照log-uniform 进行采样,采样时更加偏向稀有样本
        for target_word,context_word in positive_skip_grams:
            #[1,2]扩展维度[[1],[2]]:(1,)->(1,1)
            #正样本y
            context_class=tf.expand_dims(tf.constant([context_word],dtype='int64'),1)
            #负样本y
            negative_sampling_candidates,_,_=tf.random.log_uniform_candidate_sampler(
                true_classes=context_class,
                num_true=1,
                num_sampled=num_ns,
                unique=True,
                range_max=vocab_size,
                seed=seed,
                name='negative_sampling'
            )
            
            negative_sampling_candidates=tf.expand_dims(negative_sampling_candidates,1)
            
            # 正负样本y拼接
            context=tf.concat([context_class,negative_sampling_candidates],0)
            
            #创建标签
            label=tf.constant([1]+[0]*num_ns,dtype='int64')
            
            targets.append(target_word)
            contexts.append(context)
            labels.append(label)
            
    return targets,contexts,labels

# %%
targets,contexts,labels=generate_training_data(sequences_int,vocab_size,window_size=5, num_ns=5,seed=44)
# Out:
# 100%|██████████| 609/609 [00:34<00:00, 17.86it/s]

# %%
targets[0]
# Out:
# 10

# %%
contexts[0]
# Out:
# <tf.Tensor: shape=(6, 1), dtype=int64, numpy=
# array([[ 501],
#        [3488],
#        [  50],
#        [ 897],
#        [   1],
#        [   8]])>

# %%
labels[0]
# Out:
# <tf.Tensor: shape=(6,), dtype=int64, numpy=array([1, 0, 0, 0, 0, 0])>

# %%
print(len(targets),len(contexts),len(labels))
# Out:
# 593842 593842 593842

# %%
579*1024
# Out:
# 592896

# %%
BATCH_SIZE = 1024
BUFFER_SIZE = 10000
# 打包成(input,output),对于有多个input时((input1,input2,...),label),其中input1
dataset = tf.data.Dataset.from_tensor_slices(((targets, contexts), labels))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
print(dataset)
# Out:
# <BatchDataset shapes: (((1024,), (1024, 6, 1)), (1024, 6)), types: ((tf.int32, tf.int64), tf.int64)>

# %%
AUTOTUNE = tf.data.AUTOTUNE
# cache(),prefetch() 预加载提升速度
dataset = dataset.cache().prefetch(buffer_size=AUTOTUNE) 
print(dataset)
# Out:
# <PrefetchDataset shapes: (((1024,), (1024, 6, 1)), (1024, 6)), types: ((tf.int32, tf.int64), tf.int64)>

# %%
num_ns=5
class Word2Vec(Model):
    def __init__(self, vocab_size, embedding_dim):
        super(Word2Vec, self).__init__()
        self.target_embedding = Embedding(vocab_size, 
                                      embedding_dim,
                                      input_length=1,
                                      name="w2v_embedding", )
        self.context_embedding = Embedding(vocab_size, 
                                       embedding_dim, 
                                       input_length=num_ns+1)
        self.dots = Dot(axes=(3,2))
        self.flatten = Flatten()

    def call(self, pair):
        target, context = pair
        we = self.target_embedding(target)
        ce = self.context_embedding(context)
        dots = self.dots([ce, we])
        return self.flatten(dots)

# %%
targets[0]
# Out:
# 10

# %%
embedding_dim = 128
word2vec = Word2Vec(vocab_size, embedding_dim)
word2vec.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# 生成日志文件名称
log_dir = "./logs/fit/item2vec" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# %%
pwd
# Out:
# '/Users/vccandice/Documents/myGithub/item2vec'

# %%
word2vec.fit(dataset, epochs=10, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/3
# 579/579 [==============================] - 5s 8ms/step - loss: 0.4627 - accuracy: 0.8428
# Epoch 2/3
# 579/579 [==============================] - 5s 8ms/step - loss: 0.4529 - accuracy: 0.8457
# Epoch 3/3
# 579/579 [==============================] - 5s 8ms/step - loss: 0.4439 - accuracy: 0.8485
